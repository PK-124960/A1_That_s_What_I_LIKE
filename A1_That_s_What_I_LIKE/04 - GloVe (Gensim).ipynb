# %% [markdown]
# # GloVe (Gensim)
#
# For looking at word vectors, we'll use **Gensim**. **Gensim** isn't really a deep learning package. It's a package for for word and text similarity modeling, which started with (LDA-style) topic models and grew into SVD and neural word representations. But its efficient and scalable, and quite widely used.   We gonna use **GloVe** embeddings, downloaded at [the Glove page](https://nlp.stanford.edu/projects/glove/). They're inside [this zip file](https://nlp.stanford.edu/data/glove.6B.zip)

# %%
from gensim.test.utils import datapath
from gensim.models import KeyedVectors

# Load GloVe vectors in Word2Vec format
glove_file = datapath('glove.6B.100d.txt')
model = KeyedVectors.load_word2vec_format(glove_file, binary=False, no_header=True)

# Test
print("Vector shape for 'coffee':", model['coffee'].shape)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from gensim.test.utils import datapath
#       2 from gensim.models import KeyedVectors
#       4 # Load GloVe vectors in Word2Vec format
#
# File g:\My Drive\AT82.05 NLU\Assignments\NLP Assignments\.venv\lib\site-packages\gensim\__init__.py:11
#       7 __version__ = '4.3.3'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File g:\My Drive\AT82.05 NLU\Assignments\NLP Assignments\.venv\lib\site-packages\gensim\parsing\__init__.py:4
#       1 """This package contains functions to preprocess raw text"""
#       3 from .porter import PorterStemmer  # noqa:F401
# ----> 4 from .preprocessing import (  # noqa:F401
#       5     preprocess_documents,
#       6     preprocess_string,
#       7     read_file,
#       8     read_files,
#       9     remove_stopwords,
#      10     split_alphanum,
#      11     stem_text,
#      12     strip_multiple_whitespaces,
#      13     strip_non_alphanum,
#      14     strip_numeric,
#      15     strip_punctuation,
#      16     strip_short,
#      17     strip_tags,
#      18 )
#
# File g:\My Drive\AT82.05 NLU\Assignments\NLP Assignments\.venv\lib\site-packages\gensim\parsing\preprocessing.py:26
#      23 import string
#      24 import glob
# ---> 26 from gensim import utils
#      27 from gensim.parsing.porter import PorterStemmer
#      30 STOPWORDS = frozenset([
#      31     'all', 'six', 'just', 'less', 'being', 'indeed', 'over', 'move', 'anyway', 'four', 'not', 'own', 'through',
#      32     'using', 'fifty', 'where', 'mill', 'only', 'find', 'before', 'one', 'whose', 'system', 'how', 'somewhere',
#    (...)
#      58     'make', 'once'
#      59 ])
#
# File g:\My Drive\AT82.05 NLU\Assignments\NLP Assignments\.venv\lib\site-packages\gensim\utils.py:34
#      31 import platform
#      32 import types
# ---> 34 import numpy as np
#      35 import scipy.sparse
#      36 from smart_open import open
#
# File g:\My Drive\AT82.05 NLU\Assignments\NLP Assignments\.venv\lib\site-packages\numpy\__init__.py:194
#     191         pass
#     192 del ta
# --> 194 from . import lib
#     195 from .lib import scimath as emath
#     196 from .lib._histograms_impl import (
#     197     histogram, histogram_bin_edges, histogramdd
#     198 )
#
# File g:\My Drive\AT82.05 NLU\Assignments\NLP Assignments\.venv\lib\site-packages\numpy\lib\__init__.py:23
#      20 # Private submodules
#      21 # load module names. See https://github.com/networkx/networkx/issues/5838
#      22 from . import _type_check_impl
# ---> 23 from . import _index_tricks_impl
#      24 from . import _nanfunctions_impl
#      25 from . import _function_base_impl
#
# File g:\My Drive\AT82.05 NLU\Assignments\NLP Assignments\.venv\lib\site-packages\numpy\lib\_index_tricks_impl.py:12
#       9 from numpy._core.numeric import ScalarType, array
#      10 from numpy._core.numerictypes import issubdtype
# ---> 12 import numpy.matrixlib as matrixlib
#      13 from numpy._core.multiarray import ravel_multi_index, unravel_index
#      14 from numpy._core import overrides, linspace
#
# File g:\My Drive\AT82.05 NLU\Assignments\NLP Assignments\.venv\lib\site-packages\numpy\matrixlib\__init__.py:4
#       1 """Sub-package containing the matrix class and related functions.
#       2
#       3 """
# ----> 4 from . import defmatrix
#       5 from .defmatrix import *
#       7 __all__ = defmatrix.__all__
#
# File g:\My Drive\AT82.05 NLU\Assignments\NLP Assignments\.venv\lib\site-packages\numpy\matrixlib\defmatrix.py:12
#       9 from numpy._core.numeric import concatenate, isscalar
#      10 # While not in __all__, matrix_power used to be defined here, so we import
#      11 # it for backward compatibility.
# ---> 12 from numpy.linalg import matrix_power
#      15 def _convert_from_string(data):
#      16     for char in '[]':
#
# File g:\My Drive\AT82.05 NLU\Assignments\NLP Assignments\.venv\lib\site-packages\numpy\linalg\__init__.py:88
#      86 # To get sub-modules
#      87 from . import linalg  # deprecated in NumPy 2.0
# ---> 88 from . import _linalg
#      89 from ._linalg import *
#      91 __all__ = _linalg.__all__.copy()
#
# File g:\My Drive\AT82.05 NLU\Assignments\NLP Assignments\.venv\lib\site-packages\numpy\linalg\_linalg.py:39
#      37 from numpy.lib._twodim_base_impl import triu, eye
#      38 from numpy.lib.array_utils import normalize_axis_index, normalize_axis_tuple
# ---> 39 from numpy.linalg import _umath_linalg
#      41 from numpy._typing import NDArray
#      43 class EigResult(NamedTuple):
#
# ImportError: DLL load failed while importing _umath_linalg: The specified module could not be found.

# %% [markdown]
# ### Evaluate Analogies (Semantic and Syntactic Accuracy)

# %%
with open('word-test_semantic.txt', 'r') as file:
    data_sem = file.readlines()

with open('word-test_syntactic.txt', 'r') as file:
    data_syn = file.readlines()

# %%
def clean_data(data):
    cleaned_data = []
    for line in data:
        cleaned_line = line.strip().split()
        
        if len(cleaned_line) == 4:
            cleaned_data.append(cleaned_line)
        else:
            print(f"Skipping malformed line: {line.strip()}")
    return cleaned_data

data_sem = clean_data(data_sem)
data_syn = clean_data(data_syn)

print("Semantic Analogies:", data_sem[:2])  
print("Syntactic Analogies:", data_syn[:2])
# Out:
# Skipping malformed line: : gram8-plural
# Skipping malformed line: : gram9-plural-verbs
# Semantic Analogies: [['Athens', 'Greece', 'Baghdad', 'Iraq'], ['Athens', 'Greece', 'Bangkok', 'Thailand']]
# Syntactic Analogies: [['dancing', 'danced', 'decreasing', 'decreased'], ['dancing', 'danced', 'describing', 'described']]

# %%
def predict_glove_word(model, analogy):
    word1, word2, word3, _ = analogy  # Unpack the analogy
    try:
        predicted_word = model.most_similar(positive=[word3, word2], negative=[word1], topn=1)
        return predicted_word[0][0]  # Return the most similar word
    except KeyError:
        return '<UNK>'  # Return <UNK> if any word is out of vocabulary

# %%
def calculate_glove_accuracy(analogies, model):
    correct = 0
    total = 0
    for analogy in analogies:
        total += 1
        predicted_word = predict_glove_word(model, analogy)
        if predicted_word.lower() == analogy[3].lower():
            correct += 1

    return correct / total if total > 0 else 0

# Calculate accuracies for semantic and syntactic analogies
semantic_accuracy = calculate_glove_accuracy(data_sem, model)
syntactic_accuracy = calculate_glove_accuracy(data_syn, model)

print(f"GloVe Semantic Accuracy: {semantic_accuracy * 100:.2f}%")
print(f"GloVe Syntactic Accuracy: {syntactic_accuracy * 100:.2f}%")
# Out:
# GloVe Semantic Accuracy: 0.00%
# GloVe Syntactic Accuracy: 61.99%

# %% [markdown]
# ### Evaluate Correlation with Human Judgments

# %%
import numpy as np
from scipy.stats import spearmanr
from sklearn.metrics import mean_squared_error

def load_similarity_data(file_path):
    with open(file_path, 'r') as file:
        data = file.readlines()
    pairs = []
    scores = []
    for line in data:
        if line.strip() and len(line.strip().split()) == 3:
            word1, word2, score = line.strip().split()
            pairs.append((word1, word2))
            scores.append(float(score))
        else:
            print(f"Skipping invalid line: {line.strip()}")
    return pairs, np.array(scores)

# %%
def compute_cosine_similarity(word1, word2, model):
    try:
        return model.similarity(word1, word2)
    except KeyError:
        return 0  # If the word is not in the model, return a similarity of 0

def calculate_mse_and_correlation(model, similarity_files):
    all_true_scores = []
    all_predicted_scores = []
    
    for file_path in similarity_files:
        pairs, true_scores = load_similarity_data(file_path)
        predicted_scores = []
        
        for word1, word2 in pairs:
            similarity = compute_cosine_similarity(word1, word2, model)
            predicted_scores.append(similarity)
        
        all_true_scores.extend(true_scores)
        all_predicted_scores.extend(predicted_scores)
    
    all_true_scores = np.array(all_true_scores)
    all_predicted_scores = np.array(all_predicted_scores)
    
    # Compute MSE
    mse = mean_squared_error(all_true_scores, all_predicted_scores)
    
    # Compute Spearman correlation
    spearman_corr, _ = spearmanr(all_true_scores, all_predicted_scores)
    
    return mse, spearman_corr

# %%
similarity_files = [
    'wordsim_relatedness_goldstandard.txt',
    'wordsim_similarity_goldstandard.txt',
    'wordsim353_agreed.txt',
    'wordsim353_annotator1.txt',
    'wordsim353_annotator2.txt',
]
mse, spearman_corr = calculate_mse_and_correlation(model, similarity_files)

print(f'Mean Squared Error: {mse}')
print(f'Spearman Correlation: {spearman_corr}')
# Out:
# Skipping invalid line: #Word 1	Word 2	Human (mean)
# Skipping invalid line: # i = identical tokens
# Skipping invalid line: # s = synonym (at least in one meaning of each)
# Skipping invalid line: # a = antonyms (at least in one meaning of each)
# Skipping invalid line: # h = first is hyponym of second (at least in one meaning of each)
# Skipping invalid line: # H = first is hyperonym of second (at least in one meaning of each)
# Skipping invalid line: # S = sibling terms (terms with a common hyperonymy)
# Skipping invalid line: # m = first is part of the second one (at least in one meaning of each)
# Skipping invalid line: # M = second is part of the first one (at least in one meaning of each)
# Skipping invalid line: # t = topically related, but none of the above
# Skipping invalid line: #
# Skipping invalid line: t	love	sex	6.77
# Skipping invalid line: h	tiger	cat	7.35
# Skipping invalid line: i	tiger	tiger	10.00
# Skipping invalid line: t	book	paper	7.46
# Skipping invalid line: M	computer	keyboard	7.62
# Skipping invalid line: t	computer	internet	7.58
# Skipping invalid line: S	plane	car	5.77
# Skipping invalid line: S	train	car	6.31
# Skipping invalid line: t	telephone	communication	7.50
# Skipping invalid line: S	television	radio	6.77
# Skipping invalid line: H	media	radio	7.42
# Skipping invalid line: t	drug	abuse	6.85
# Skipping invalid line: S	bread	butter	6.19
# Skipping invalid line: S	cucumber	potato	5.92
# Skipping invalid line: S	doctor	nurse	7.00
# Skipping invalid line: S	professor	doctor	6.62
# Skipping invalid line: S	student	professor	6.81
# Skipping invalid line: t	smart	student	4.62
# Skipping invalid line: a	smart	stupid	5.81
# Skipping invalid line: t	company	stock	7.08
# Skipping invalid line: t	stock	market	8.08
# Skipping invalid line: t	stock	phone	1.62
# Skipping invalid line: t	stock	CD	1.31
# Skipping invalid line: t	stock	jaguar	0.92
# Skipping invalid line: t	stock	egg	1.81
# Skipping invalid line: t	fertility	egg	6.69
# Skipping invalid line: t	stock	live	3.73
# Skipping invalid line: t	stock	life	0.92
# Skipping invalid line: t	book	library	7.46
# Skipping invalid line: t	bank	money	8.12
# Skipping invalid line: s	wood	forest	7.73
# Skipping invalid line: H	money	cash	9.15
# Skipping invalid line: t	professor	cucumber	0.31
# Skipping invalid line: t	king	cabbage	0.23
# Skipping invalid line: S	king	queen	8.58
# Skipping invalid line: S	king	rook	5.92
# Skipping invalid line: S	bishop	rabbi	6.69
# Skipping invalid line: m	Jerusalem	Israel	8.46
# Skipping invalid line: t	Jerusalem	Palestinian	7.65
# Skipping invalid line: t	holy	sex	1.62
# Skipping invalid line: s	fuck	sex	9.44
# Skipping invalid line: t	Maradona	football	8.62
# Skipping invalid line: s	football	soccer	9.03
# Skipping invalid line: S	football	basketball	6.81
# Skipping invalid line: S	football	tennis	6.63
# Skipping invalid line: t	tennis	racket	7.56
# Skipping invalid line: t	Arafat	peace	6.73
# Skipping invalid line: t	Arafat	terror	7.65
# Skipping invalid line: S	Arafat	Jackson	2.50
# Skipping invalid line: t	law	lawyer	8.38
# Skipping invalid line: t	movie	star	7.38
# Skipping invalid line: t	movie	popcorn	6.19
# Skipping invalid line: t	movie	critic	6.73
# Skipping invalid line: t	movie	theater	7.92
# Skipping invalid line: t	physics	proton	8.12
# Skipping invalid line: S	physics	chemistry	7.35
# Skipping invalid line: t	space	chemistry	4.88
# Skipping invalid line: t	alcohol	chemistry	5.54
# Skipping invalid line: S	vodka	gin	8.46
# Skipping invalid line: S	vodka	brandy	8.13
# Skipping invalid line: t	drink	car	3.04
# Skipping invalid line: t	drink	ear	1.31
# Skipping invalid line: t	drink	mouth	5.96
# Skipping invalid line: S	drink	eat	6.87
# Skipping invalid line: t	baby	mother	7.85
# Skipping invalid line: t	drink	mother	2.65
# Skipping invalid line: s	car	automobile	8.94
# Skipping invalid line: s	gem	jewel	8.96
# Skipping invalid line: s	journey	voyage	9.29
# Skipping invalid line: s	boy	lad	8.83
# Skipping invalid line: s	coast	shore	9.10
# Skipping invalid line: s	asylum	madhouse	8.87
# Skipping invalid line: s	magician	wizard	9.02
# Skipping invalid line: s	midday	noon	9.29
# Skipping invalid line: s	furnace	stove	8.79
# Skipping invalid line: H	food	fruit	7.52
# Skipping invalid line: H	bird	cock	7.10
# Skipping invalid line: H	bird	crane	7.38
# Skipping invalid line: t	tool	implement	6.46
# Skipping invalid line: t	brother	monk	6.27
# Skipping invalid line: t	crane	implement	2.69
# Skipping invalid line: t	lad	brother	4.46
# Skipping invalid line: t	journey	car	5.85
# Skipping invalid line: t	monk	oracle	5.00
# Skipping invalid line: t	cemetery	woodland	2.08
# Skipping invalid line: H	food	rooster	4.42
# Skipping invalid line: t	coast	hill	4.38
# Skipping invalid line: t	forest	graveyard	1.85
# Skipping invalid line: t	shore	woodland	3.08
# Skipping invalid line: t	monk	slave	0.92
# Skipping invalid line: t	coast	forest	3.15
# Skipping invalid line: t	lad	wizard	0.92
# Skipping invalid line: t	chord	smile	0.54
# Skipping invalid line: t	glass	magician	2.08
# Skipping invalid line: t	noon	string	0.54
# Skipping invalid line: t	rooster	voyage	0.62
# Skipping invalid line: H	money	dollar	8.42
# Skipping invalid line: H	money	currency	9.04
# Skipping invalid line: t	money	wealth	8.27
# Skipping invalid line: t	money	property	7.57
# Skipping invalid line: t	money	possession	7.29
# Skipping invalid line: t	money	bank	8.50
# Skipping invalid line: t	money	deposit	7.73
# Skipping invalid line: t	money	withdrawal	6.88
# Skipping invalid line: t	money	laundering	5.65
# Skipping invalid line: t	money	operation	3.31
# Skipping invalid line: S	tiger	jaguar	8.00
# Skipping invalid line: h	tiger	feline	8.00
# Skipping invalid line: h	tiger	carnivore	7.08
# Skipping invalid line: h	tiger	mammal	6.85
# Skipping invalid line: h	tiger	animal	7.00
# Skipping invalid line: h	tiger	organism	4.77
# Skipping invalid line: h	tiger	fauna	5.62
# Skipping invalid line: t	tiger	zoo	5.87
# Skipping invalid line: S	psychology	psychiatry	8.08
# Skipping invalid line: t	psychology	anxiety	7.00
# Skipping invalid line: t	psychology	fear	6.85
# Skipping invalid line: t	psychology	depression	7.42
# Skipping invalid line: t	psychology	clinic	6.58
# Skipping invalid line: t	psychology	doctor	6.42
# Skipping invalid line: t	psychology	Freud	8.21
# Skipping invalid line: t	psychology	mind	7.69
# Skipping invalid line: t	psychology	health	7.23
# Skipping invalid line: h	psychology	science	6.71
# Skipping invalid line: h	psychology	discipline	5.58
# Skipping invalid line: t	psychology	cognition	7.48
# Skipping invalid line: S	planet	star	8.45
# Skipping invalid line: t	planet	constellation	8.06
# Skipping invalid line: S	planet	moon	8.08
# Skipping invalid line: S	planet	sun	8.02
# Skipping invalid line: m	planet	galaxy	8.11
# Skipping invalid line: t	planet	space	7.92
# Skipping invalid line: t	planet	astronomer	7.94
# Skipping invalid line: h	precedent	example	5.85
# Skipping invalid line: t	precedent	information	3.85
# Skipping invalid line: t	precedent	cognition	2.81
# Skipping invalid line: t	precedent	law	6.65
# Skipping invalid line: t	precedent	collection	2.50
# Skipping invalid line: t	precedent	group	1.77
# Skipping invalid line: S	precedent	antecedent	6.04
# Skipping invalid line: t	cup	coffee	6.58
# Skipping invalid line: h	cup	tableware	6.85
# Skipping invalid line: t	cup	article	2.40
# Skipping invalid line: h	cup	artifact	2.92
# Skipping invalid line: h	cup	object	3.69
# Skipping invalid line: h	cup	entity	2.15
# Skipping invalid line: t	cup	drink	7.25
# Skipping invalid line: t	cup	food	5.00
# Skipping invalid line: t	cup	substance	1.92
# Skipping invalid line: t	cup	liquid	5.90
# Skipping invalid line: h	jaguar	cat	7.42
# Skipping invalid line: h	jaguar	car	7.27
# Skipping invalid line: t	energy	secretary	1.81
# Skipping invalid line: t	secretary	senate	5.06
# Skipping invalid line: t	energy	laboratory	5.09
# Skipping invalid line: t	computer	laboratory	6.78
# Skipping invalid line: t	weapon	secret	6.06
# Skipping invalid line: t	FBI	fingerprint	6.94
# Skipping invalid line: t	FBI	investigation	8.31
# Skipping invalid line: t	investigation	effort	4.59
# Skipping invalid line: t	Mars	water	2.94
# Skipping invalid line: t	Mars	scientist	5.63
# Skipping invalid line: t	news	report	8.16
# Skipping invalid line: m	canyon	landscape	7.53
# Skipping invalid line: t	image	surface	4.56
# Skipping invalid line: t	discovery	space	6.34
# Skipping invalid line: t	water	seepage	6.56
# Skipping invalid line: t	sign	recess	2.38
# Skipping invalid line: t	Wednesday	news	2.22
# Skipping invalid line: S	mile	kilometer	8.66
# Skipping invalid line: t	computer	news	4.47
# Skipping invalid line: t	territory	surface	5.34
# Skipping invalid line: t	atmosphere	landscape	3.69
# Skipping invalid line: t	president	medal	3.00
# Skipping invalid line: t	war	troops	8.13
# Skipping invalid line: t	record	number	6.31
# Skipping invalid line: S	skin	eye	6.22
# Skipping invalid line: S	Japanese	American	6.50
# Skipping invalid line: t	theater	history	3.91
# Skipping invalid line: t	volunteer	motto	2.56
# Skipping invalid line: t	prejudice	recognition	3.00
# Skipping invalid line: t	decoration	valor	5.63
# Skipping invalid line: S	century	year	7.59
# Skipping invalid line: t	century	nation	3.16
# Skipping invalid line: t	delay	racism	1.19
# Skipping invalid line: t	delay	news	3.31
# Skipping invalid line: t	minister	party	6.63
# Skipping invalid line: t	peace	plan	4.75
# Skipping invalid line: t	minority	peace	3.69
# Skipping invalid line: t	attempt	peace	4.25
# Skipping invalid line: t	government	crisis	6.56
# Skipping invalid line: t	deployment	departure	4.25
# Skipping invalid line: t	deployment	withdrawal	5.88
# Skipping invalid line: t	energy	crisis	5.94
# Skipping invalid line: h	announcement	news	7.56
# Skipping invalid line: t	announcement	effort	2.75
# Skipping invalid line: t	stroke	hospital	7.03
# Skipping invalid line: t	disability	death	5.47
# Skipping invalid line: t	victim	emergency	6.47
# Skipping invalid line: t	treatment	recovery	7.91
# Skipping invalid line: t	journal	association	4.97
# Skipping invalid line: h	doctor	personnel	5.00
# Skipping invalid line: t	doctor	liability	5.19
# Skipping invalid line: t	liability	insurance	7.03
# Skipping invalid line: t	school	center	3.44
# Skipping invalid line: t	reason	hypertension	2.31
# Skipping invalid line: t	reason	criterion	5.91
# Skipping invalid line: t	hundred	percent	7.38
# Skipping invalid line: S	Harvard	Yale	8.13
# Skipping invalid line: h	hospital	infrastructure	4.63
# Skipping invalid line: t	death	row	5.25
# Skipping invalid line: t	death	inmate	5.03
# Skipping invalid line: t	lawyer	evidence	6.69
# Skipping invalid line: S	life	death	7.88
# Skipping invalid line: t	life	term	4.50
# Skipping invalid line: t	word	similarity	4.75
# Skipping invalid line: t	board	recommendation	4.47
# Skipping invalid line: t	governor	interview	3.25
# Skipping invalid line: M	OPEC	country	5.63
# Skipping invalid line: t	peace	atmosphere	3.69
# Skipping invalid line: t	peace	insurance	2.94
# Skipping invalid line: t	territory	kilometer	5.28
# Skipping invalid line: h	travel	activity	5.00
# Skipping invalid line: t	competition	price	6.44
# Skipping invalid line: t	consumer	confidence	4.13
# Skipping invalid line: t	consumer	energy	4.75
# Skipping invalid line: t	problem	airport	2.38
# Skipping invalid line: t	car	flight	4.94
# Skipping invalid line: t	credit	card	8.06
# Skipping invalid line: t	credit	information	5.31
# Skipping invalid line: t	hotel	reservation	8.03
# Skipping invalid line: t	grocery	money	5.94
# Skipping invalid line: t	registration	arrangement	6.00
# Skipping invalid line: t	arrangement	accommodation	5.41
# Skipping invalid line: t	month	hotel	1.81
# Skipping invalid line: s	type	kind	8.97
# Skipping invalid line: t	arrival	hotel	6.00
# Skipping invalid line: t	bed	closet	6.72
# Skipping invalid line: t	closet	clothes	8.00
# Skipping invalid line: t	situation	conclusion	4.81
# Skipping invalid line: t	situation	isolation	3.88
# Skipping invalid line: t	impartiality	interest	5.16
# Skipping invalid line: t	direction	combination	2.25
# Skipping invalid line: h	street	place	6.44
# Skipping invalid line: H	street	avenue	8.88
# Skipping invalid line: S	street	block	6.88
# Skipping invalid line: t	street	children	4.94
# Skipping invalid line: t	listing	proximity	2.56
# Skipping invalid line: t	listing	category	6.38
# Skipping invalid line: h	cell	phone	7.81
# Skipping invalid line: t	production	hike	1.75
# Skipping invalid line: t	benchmark	index	4.25
# Skipping invalid line: t	media	trading	3.88
# Skipping invalid line: t	media	gain	2.88
# Skipping invalid line: h	dividend	payment	7.63
# Skipping invalid line: t	dividend	calculation	6.48
# Skipping invalid line: s	calculation	computation	8.44
# Skipping invalid line: t	currency	market	7.50
# Skipping invalid line: t	OPEC	oil	8.59
# Skipping invalid line: t	oil	stock	6.34
# Skipping invalid line: t	announcement	production	3.38
# Skipping invalid line: t	announcement	warning	6.00
# Skipping invalid line: t	profit	warning	3.88
# Skipping invalid line: S	profit	loss	7.63
# Skipping invalid line: S	dollar	yen	7.78
# Skipping invalid line: s	dollar	buck	9.22
# Skipping invalid line: t	dollar	profit	7.38
# Skipping invalid line: t	dollar	loss	6.09
# Skipping invalid line: t	computer	software	8.50
# Skipping invalid line: t	network	hardware	8.31
# Skipping invalid line: h	phone	equipment	7.13
# Skipping invalid line: t	equipment	maker	5.91
# Skipping invalid line: t	luxury	car	6.47
# Skipping invalid line: t	five	month	3.38
# Skipping invalid line: t	report	gain	3.63
# Skipping invalid line: t	investor	earning	7.13
# Skipping invalid line: H	liquid	water	7.89
# Skipping invalid line: t	baseball	season	5.97
# Skipping invalid line: t	game	victory	7.03
# Skipping invalid line: t	game	team	7.69
# Skipping invalid line: S	marathon	sprint	7.47
# Skipping invalid line: t	game	series	6.19
# Skipping invalid line: t	game	defeat	6.97
# Skipping invalid line: t	seven	series	3.56
# Skipping invalid line: t	seafood	sea	7.47
# Skipping invalid line: h	seafood	food	8.34
# Skipping invalid line: H	seafood	lobster	8.70
# Skipping invalid line: h	lobster	food	7.81
# Skipping invalid line: S	lobster	wine	5.70
# Skipping invalid line: t	food	preparation	6.22
# Skipping invalid line: t	video	archive	6.34
# Skipping invalid line: t	start	year	4.06
# Skipping invalid line: t	start	match	4.47
# Skipping invalid line: t	game	round	5.97
# Skipping invalid line: t	boxing	round	7.61
# Skipping invalid line: s	championship	tournament	8.36
# Skipping invalid line: t	fighting	defeating	7.41
# Skipping invalid line: t	line	insurance	2.69
# Skipping invalid line: m	day	summer	3.94
# Skipping invalid line: t	summer	drought	7.16
# Skipping invalid line: t	summer	nature	5.63
# Skipping invalid line: M	day	dawn	7.53
# Skipping invalid line: t	nature	environment	8.31
# Skipping invalid line: t	environment	ecology	8.81
# Skipping invalid line: t	nature	man	6.25
# Skipping invalid line: S	man	woman	8.30
# Skipping invalid line: H	man	governor	5.25
# Skipping invalid line: s	murder	manslaughter	8.53
# Skipping invalid line: t	soap	opera	7.94
# Skipping invalid line: h	opera	performance	6.88
# Skipping invalid line: t	life	lesson	5.94
# Skipping invalid line: t	focus	life	4.06
# Skipping invalid line: t	production	crew	6.25
# Skipping invalid line: t	television	film	7.72
# Skipping invalid line: t	lover	quarrel	6.19
# Skipping invalid line: t	viewer	serial	2.97
# Skipping invalid line: t	possibility	girl	1.94
# Skipping invalid line: t	population	development	3.75
# Skipping invalid line: t	morality	importance	3.31
# Skipping invalid line: t	morality	marriage	3.69
# Skipping invalid line: S	Mexico	Brazil	7.44
# Skipping invalid line: t	gender	equality	6.41
# Skipping invalid line: t	change	attitude	5.44
# Skipping invalid line: t	family	planning	6.25
# Skipping invalid line: t	opera	industry	2.63
# Skipping invalid line: t	sugar	approach	0.88
# Skipping invalid line: t	practice	institution	3.19
# Skipping invalid line: t	ministry	culture	4.69
# Skipping invalid line: t	problem	challenge	6.75
# Skipping invalid line: t	size	prominence	5.31
# Skipping invalid line: M	country	citizen	7.31
# Skipping invalid line: M	planet	people	5.75
# Skipping invalid line: t	development	issue	3.97
# Skipping invalid line: t	experience	music	3.47
# Skipping invalid line: t	music	project	3.63
# Skipping invalid line: S	glass	metal	5.56
# Skipping invalid line: h	aluminum	metal	7.83
# Skipping invalid line: t	chance	credibility	3.88
# Skipping invalid line: t	exhibit	memorabilia	5.31
# Skipping invalid line: t	concert	virtuoso	6.81
# Skipping invalid line: S	rock	jazz	7.59
# Skipping invalid line: S	museum	theater	7.19
# Skipping invalid line: t	observation	architecture	4.38
# Skipping invalid line: t	space	world	6.53
# Skipping invalid line: t	preservation	world	6.19
# Skipping invalid line: t	admission	ticket	7.69
# Skipping invalid line: S	shower	thunderstorm	6.31
# Skipping invalid line: t	shower	flood	6.03
# Skipping invalid line: t	weather	forecast	8.34
# Skipping invalid line: t	disaster	area	6.25
# Skipping invalid line: t	governor	office	6.34
# Skipping invalid line: t	architecture	century	3.78
# Skipping invalid line: #Word 1	Word 2	Human (mean)
# Skipping invalid line: # i = identical tokens
# Skipping invalid line: # s = synonym (at least in one meaning of each)
# Skipping invalid line: # a = antonyms (at least in one meaning of each)
# Skipping invalid line: # h = first is hyponym of second (at least in one meaning of each)
# Skipping invalid line: # H = first is hyperonym of second (at least in one meaning of each)
# Skipping invalid line: # S = sibling terms (terms with a common hyperonymy)
# Skipping invalid line: # m = first is part of the second one (at least in one meaning of each)
# Skipping invalid line: # M = second is part of the first one (at least in one meaning of each)
# Skipping invalid line: # t = topically related, but none of the above
# Skipping invalid line: #
# Skipping invalid line: t	love	sex	6.77
# Skipping invalid line: h	tiger	cat	7.35
# Skipping invalid line: i	tiger	tiger	10.00
# Skipping invalid line: t	book	paper	7.46
# Skipping invalid line: M	computer	keyboard	7.62
# Skipping invalid line: t	computer	internet	7.58
# Skipping invalid line: S	plane	car	5.77
# Skipping invalid line: S	train	car	6.31
# Skipping invalid line: t	telephone	communication	7.50
# Skipping invalid line: S	television	radio	6.77
# Skipping invalid line: t	media	radio	7.42
# Skipping invalid line: t	drug	abuse	6.85
# Skipping invalid line: t	bread	butter	6.19
# Skipping invalid line: S	cucumber	potato	5.92
# Skipping invalid line: S	doctor	nurse	7.00
# Skipping invalid line: t	professor	doctor	6.62
# Skipping invalid line: S	student	professor	6.81
# Skipping invalid line: t	smart	student	4.62
# Skipping invalid line: a	smart	stupid	5.81
# Skipping invalid line: M	company	stock	7.08
# Skipping invalid line: t	stock	market	8.08
# Skipping invalid line: t	stock	phone	1.62
# Skipping invalid line: t	stock	CD	1.31
# Skipping invalid line: t	stock	jaguar	0.92
# Skipping invalid line: t	stock	egg	1.81
# Skipping invalid line: t	fertility	egg	6.69
# Skipping invalid line: t	stock	live	3.73
# Skipping invalid line: t	stock	life	0.92
# Skipping invalid line: m	book	library	7.46
# Skipping invalid line: M	bank	money	8.12
# Skipping invalid line: s	wood	forest	7.73
# Skipping invalid line: H	money	cash	9.15
# Skipping invalid line: t	professor	cucumber	0.31
# Skipping invalid line: t	king	cabbage	0.23
# Skipping invalid line: S	king	queen	8.58
# Skipping invalid line: S	king	rook	5.92
# Skipping invalid line: S	bishop	rabbi	6.69
# Skipping invalid line: m	Jerusalem	Israel	8.46
# Skipping invalid line: t	Jerusalem	Palestinian	7.65
# Skipping invalid line: t	holy	sex	1.62
# Skipping invalid line: h	fuck	sex	9.44
# Skipping invalid line: t	Maradona	football	8.62
# Skipping invalid line: s	football	soccer	9.03
# Skipping invalid line: S	football	basketball	6.81
# Skipping invalid line: S	football	tennis	6.63
# Skipping invalid line: t	tennis	racket	7.56
# Skipping invalid line: t	Arafat	peace	6.73
# Skipping invalid line: t	Arafat	terror	7.65
# Skipping invalid line: t	Arafat	Jackson	2.50
# Skipping invalid line: t	law	lawyer	8.38
# Skipping invalid line: t	movie	star	7.38
# Skipping invalid line: t	movie	popcorn	6.19
# Skipping invalid line: t	movie	critic	6.73
# Skipping invalid line: t	movie	theater	7.92
# Skipping invalid line: t	physics	proton	8.12
# Skipping invalid line: S	physics	chemistry	7.35
# Skipping invalid line: t	space	chemistry	4.88
# Skipping invalid line: t	alcohol	chemistry	5.54
# Skipping invalid line: S	vodka	gin	8.46
# Skipping invalid line: S	vodka	brandy	8.13
# Skipping invalid line: t	drink	car	3.04
# Skipping invalid line: t	drink	ear	1.31
# Skipping invalid line: t	drink	mouth	5.96
# Skipping invalid line: S	drink	eat	6.87
# Skipping invalid line: t	baby	mother	7.85
# Skipping invalid line: t	drink	mother	2.65
# Skipping invalid line: s	car	automobile	8.94
# Skipping invalid line: s	gem	jewel	8.96
# Skipping invalid line: s	journey	voyage	9.29
# Skipping invalid line: s	boy	lad	8.83
# Skipping invalid line: s	coast	shore	9.10
# Skipping invalid line: s	asylum	madhouse	8.87
# Skipping invalid line: s	magician	wizard	9.02
# Skipping invalid line: s	midday	noon	9.29
# Skipping invalid line: s	furnace	stove	8.79
# Skipping invalid line: H	food	fruit	7.52
# Skipping invalid line: H	bird	cock	7.10
# Skipping invalid line: H	bird	crane	7.38
# Skipping invalid line: s	tool	implement	6.46
# Skipping invalid line: s	brother	monk	6.27
# Skipping invalid line: t	crane	implement	2.69
# Skipping invalid line: t	lad	brother	4.46
# Skipping invalid line: t	journey	car	5.85
# Skipping invalid line: t	monk	oracle	5.00
# Skipping invalid line: S	cemetery	woodland	2.08
# Skipping invalid line: H	food	rooster	4.42
# Skipping invalid line: S	coast	hill	4.38
# Skipping invalid line: S	forest	graveyard	1.85
# Skipping invalid line: S	shore	woodland	3.08
# Skipping invalid line: t	monk	slave	0.92
# Skipping invalid line: S	coast	forest	3.15
# Skipping invalid line: t	lad	wizard	0.92
# Skipping invalid line: t	chord	smile	0.54
# Skipping invalid line: t	glass	magician	2.08
# Skipping invalid line: t	noon	string	0.54
# Skipping invalid line: t	rooster	voyage	0.62
# Skipping invalid line: H	money	dollar	8.42
# Skipping invalid line: H	money	currency	9.04
# Skipping invalid line: t	money	wealth	8.27
# Skipping invalid line: t	money	property	7.57
# Skipping invalid line: h	money	possession	7.29
# Skipping invalid line: m	money	bank	8.50
# Skipping invalid line: m	money	deposit	7.73
# Skipping invalid line: t	money	withdrawal	6.88
# Skipping invalid line: t	money	laundering	5.65
# Skipping invalid line: t	money	operation	3.31
# Skipping invalid line: S	tiger	jaguar	8.00
# Skipping invalid line: h	tiger	feline	8.00
# Skipping invalid line: h	tiger	carnivore	7.08
# Skipping invalid line: h	tiger	mammal	6.85
# Skipping invalid line: h	tiger	animal	7.00
# Skipping invalid line: h	tiger	organism	4.77
# Skipping invalid line: t	tiger	fauna	5.62
# Skipping invalid line: t	tiger	zoo	5.87
# Skipping invalid line: S	psychology	psychiatry	8.08
# Skipping invalid line: t	psychology	anxiety	7.00
# Skipping invalid line: t	psychology	fear	6.85
# Skipping invalid line: t	psychology	depression	7.42
# Skipping invalid line: t	psychology	clinic	6.58
# Skipping invalid line: t	psychology	doctor	6.42
# Skipping invalid line: t	psychology	Freud	8.21
# Skipping invalid line: t	psychology	mind	7.69
# Skipping invalid line: t	psychology	health	7.23
# Skipping invalid line: h	psychology	science	6.71
# Skipping invalid line: h	psychology	discipline	5.58
# Skipping invalid line: t	psychology	cognition	7.48
# Skipping invalid line: S	planet	star	8.45
# Skipping invalid line: m	planet	constellation	8.06
# Skipping invalid line: M	planet	moon	8.08
# Skipping invalid line: m	planet	sun	8.02
# Skipping invalid line: m	planet	galaxy	8.11
# Skipping invalid line: t	planet	space	7.92
# Skipping invalid line: t	planet	astronomer	7.94
# Skipping invalid line: h	precedent	example	5.85
# Skipping invalid line: t	precedent	information	3.85
# Skipping invalid line: t	precedent	cognition	2.81
# Skipping invalid line: t	precedent	law	6.65
# Skipping invalid line: t	precedent	collection	2.50
# Skipping invalid line: t	precedent	group	1.77
# Skipping invalid line: s	precedent	antecedent	6.04
# Skipping invalid line: t	cup	coffee	6.58
# Skipping invalid line: h	cup	tableware	6.85
# Skipping invalid line: t	cup	article	2.40
# Skipping invalid line: h	cup	artifact	2.92
# Skipping invalid line: h	cup	object	3.69
# Skipping invalid line: h	cup	entity	2.15
# Skipping invalid line: t	cup	drink	7.25
# Skipping invalid line: t	cup	food	5.00
# Skipping invalid line: t	cup	substance	1.92
# Skipping invalid line: t	cup	liquid	5.90
# Skipping invalid line: h	jaguar	cat	7.42
# Skipping invalid line: h	jaguar	car	7.27
# Skipping invalid line: t	energy	secretary	1.81
# Skipping invalid line: t	secretary	senate	5.06
# Skipping invalid line: t	energy	laboratory	5.09
# Skipping invalid line: t	computer	laboratory	6.78
# Skipping invalid line: t	weapon	secret	6.06
# Skipping invalid line: t	FBI	fingerprint	6.94
# Skipping invalid line: t	FBI	investigation	8.31
# Skipping invalid line: h	investigation	effort	4.59
# Skipping invalid line: t	Mars	water	2.94
# Skipping invalid line: t	Mars	scientist	5.63
# Skipping invalid line: t	news	report	8.16
# Skipping invalid line: m	canyon	landscape	7.53
# Skipping invalid line: t	image	surface	4.56
# Skipping invalid line: t	discovery	space	6.34
# Skipping invalid line: t	water	seepage	6.56
# Skipping invalid line: t	sign	recess	2.38
# Skipping invalid line: t	Wednesday	news	2.22
# Skipping invalid line: S	mile	kilometer	8.66
# Skipping invalid line: t	computer	news	4.47
# Skipping invalid line: t	territory	surface	5.34
# Skipping invalid line: t	atmosphere	landscape	3.69
# Skipping invalid line: t	president	medal	3.00
# Skipping invalid line: t	war	troops	8.13
# Skipping invalid line: h	record	number	6.31
# Skipping invalid line: t	skin	eye	6.22
# Skipping invalid line: S	Japanese	American	6.50
# Skipping invalid line: t	theater	history	3.91
# Skipping invalid line: t	volunteer	motto	2.56
# Skipping invalid line: t	prejudice	recognition	3.00
# Skipping invalid line: t	decoration	valor	5.63
# Skipping invalid line: S	century	year	7.59
# Skipping invalid line: t	century	nation	3.16
# Skipping invalid line: t	delay	racism	1.19
# Skipping invalid line: t	delay	news	3.31
# Skipping invalid line: t	minister	party	6.63
# Skipping invalid line: t	peace	plan	4.75
# Skipping invalid line: t	minority	peace	3.69
# Skipping invalid line: t	attempt	peace	4.25
# Skipping invalid line: t	government	crisis	6.56
# Skipping invalid line: t	deployment	departure	4.25
# Skipping invalid line: t	deployment	withdrawal	5.88
# Skipping invalid line: t	energy	crisis	5.94
# Skipping invalid line: h	announcement	news	7.56
# Skipping invalid line: t	announcement	effort	2.75
# Skipping invalid line: t	stroke	hospital	7.03
# Skipping invalid line: t	disability	death	5.47
# Skipping invalid line: t	victim	emergency	6.47
# Skipping invalid line: t	treatment	recovery	7.91
# Skipping invalid line: t	journal	association	4.97
# Skipping invalid line: h	doctor	personnel	5.00
# Skipping invalid line: t	doctor	liability	5.19
# Skipping invalid line: t	liability	insurance	7.03
# Skipping invalid line: h	school	center	3.44
# Skipping invalid line: t	reason	hypertension	2.31
# Skipping invalid line: t	reason	criterion	5.91
# Skipping invalid line: t	hundred	percent	7.38
# Skipping invalid line: S	Harvard	Yale	8.13
# Skipping invalid line: h	hospital	infrastructure	4.63
# Skipping invalid line: t	death	row	5.25
# Skipping invalid line: t	death	inmate	5.03
# Skipping invalid line: t	lawyer	evidence	6.69
# Skipping invalid line: t	life	death	7.88
# Skipping invalid line: t	life	term	4.50
# Skipping invalid line: t	word	similarity	4.75
# Skipping invalid line: t	board	recommendation	4.47
# Skipping invalid line: t	governor	interview	3.25
# Skipping invalid line: M	OPEC	country	5.63
# Skipping invalid line: t	peace	atmosphere	3.69
# Skipping invalid line: t	peace	insurance	2.94
# Skipping invalid line: t	territory	kilometer	5.28
# Skipping invalid line: h	travel	activity	5.00
# Skipping invalid line: t	competition	price	6.44
# Skipping invalid line: t	consumer	confidence	4.13
# Skipping invalid line: t	consumer	energy	4.75
# Skipping invalid line: t	problem	airport	2.38
# Skipping invalid line: t	car	flight	4.94
# Skipping invalid line: t	credit	card	8.06
# Skipping invalid line: t	credit	information	5.31
# Skipping invalid line: t	hotel	reservation	8.03
# Skipping invalid line: t	grocery	money	5.94
# Skipping invalid line: t	registration	arrangement	6.00
# Skipping invalid line: t	arrangement	accommodation	5.41
# Skipping invalid line: t	month	hotel	1.81
# Skipping invalid line: s	type	kind	8.97
# Skipping invalid line: t	arrival	hotel	6.00
# Skipping invalid line: t	bed	closet	6.72
# Skipping invalid line: t	closet	clothes	8.00
# Skipping invalid line: t	situation	conclusion	4.81
# Skipping invalid line: t	situation	isolation	3.88
# Skipping invalid line: t	impartiality	interest	5.16
# Skipping invalid line: t	direction	combination	2.25
# Skipping invalid line: h	street	place	6.44
# Skipping invalid line: H	street	avenue	8.88
# Skipping invalid line: t	street	block	6.88
# Skipping invalid line: t	street	children	4.94
# Skipping invalid line: t	listing	proximity	2.56
# Skipping invalid line: M	listing	category	6.38
# Skipping invalid line: t	cell	phone	7.81
# Skipping invalid line: t	production	hike	1.75
# Skipping invalid line: t	benchmark	index	4.25
# Skipping invalid line: t	media	trading	3.88
# Skipping invalid line: t	media	gain	2.88
# Skipping invalid line: h	dividend	payment	7.63
# Skipping invalid line: t	dividend	calculation	6.48
# Skipping invalid line: s	calculation	computation	8.44
# Skipping invalid line: t	currency	market	7.50
# Skipping invalid line: t	OPEC	oil	8.59
# Skipping invalid line: t	oil	stock	6.34
# Skipping invalid line: t	announcement	production	3.38
# Skipping invalid line: H	announcement	warning	6.00
# Skipping invalid line: t	profit	warning	3.88
# Skipping invalid line: t	profit	loss	7.63
# Skipping invalid line: S	dollar	yen	7.78
# Skipping invalid line: s	dollar	buck	9.22
# Skipping invalid line: t	dollar	profit	7.38
# Skipping invalid line: t	dollar	loss	6.09
# Skipping invalid line: t	computer	software	8.50
# Skipping invalid line: t	network	hardware	8.31
# Skipping invalid line: h	phone	equipment	7.13
# Skipping invalid line: t	equipment	maker	5.91
# Skipping invalid line: t	luxury	car	6.47
# Skipping invalid line: t	five	month	3.38
# Skipping invalid line: t	report	gain	3.63
# Skipping invalid line: t	investor	earning	7.13
# Skipping invalid line: t	liquid	water	7.89
# Skipping invalid line: t	baseball	season	5.97
# Skipping invalid line: t	game	victory	7.03
# Skipping invalid line: t	game	team	7.69
# Skipping invalid line: M	marathon	sprint	7.47
# Skipping invalid line: t	game	series	6.19
# Skipping invalid line: t	game	defeat	6.97
# Skipping invalid line: t	seven	series	3.56
# Skipping invalid line: t	seafood	sea	7.47
# Skipping invalid line: h	seafood	food	8.34
# Skipping invalid line: H	seafood	lobster	8.70
# Skipping invalid line: h	lobster	food	7.81
# Skipping invalid line: t	lobster	wine	5.70
# Skipping invalid line: t	food	preparation	6.22
# Skipping invalid line: t	video	archive	6.34
# Skipping invalid line: t	start	year	4.06
# Skipping invalid line: t	start	match	4.47
# Skipping invalid line: M	game	round	5.97
# Skipping invalid line: t	boxing	round	7.61
# Skipping invalid line: s	championship	tournament	8.36
# Skipping invalid line: t	fighting	defeating	7.41
# Skipping invalid line: t	line	insurance	2.69
# Skipping invalid line: m	day	summer	3.94
# Skipping invalid line: t	summer	drought	7.16
# Skipping invalid line: t	summer	nature	5.63
# Skipping invalid line: M	day	dawn	7.53
# Skipping invalid line: t	nature	environment	8.31
# Skipping invalid line: t	environment	ecology	8.81
# Skipping invalid line: t	nature	man	6.25
# Skipping invalid line: S	man	woman	8.30
# Skipping invalid line: H	man	governor	5.25
# Skipping invalid line: s	murder	manslaughter	8.53
# Skipping invalid line: t	soap	opera	7.94
# Skipping invalid line: h	opera	performance	6.88
# Skipping invalid line: t	life	lesson	5.94
# Skipping invalid line: t	focus	life	4.06
# Skipping invalid line: t	production	crew	6.25
# Skipping invalid line: t	television	film	7.72
# Skipping invalid line: t	lover	quarrel	6.19
# Skipping invalid line: t	viewer	serial	2.97
# Skipping invalid line: t	possibility	girl	1.94
# Skipping invalid line: t	population	development	3.75
# Skipping invalid line: t	morality	importance	3.31
# Skipping invalid line: t	morality	marriage	3.69
# Skipping invalid line: S	Mexico	Brazil	7.44
# Skipping invalid line: t	gender	equality	6.41
# Skipping invalid line: t	change	attitude	5.44
# Skipping invalid line: t	family	planning	6.25
# Skipping invalid line: t	opera	industry	2.63
# Skipping invalid line: t	sugar	approach	0.88
# Skipping invalid line: t	practice	institution	3.19
# Skipping invalid line: t	ministry	culture	4.69
# Skipping invalid line: t	problem	challenge	6.75
# Skipping invalid line: t	size	prominence	5.31
# Skipping invalid line: M	country	citizen	7.31
# Skipping invalid line: t	planet	people	5.75
# Skipping invalid line: t	development	issue	3.97
# Skipping invalid line: t	experience	music	3.47
# Skipping invalid line: t	music	project	3.63
# Skipping invalid line: S	glass	metal	5.56
# Skipping invalid line: h	aluminum	metal	7.83
# Skipping invalid line: t	chance	credibility	3.88
# Skipping invalid line: t	exhibit	memorabilia	5.31
# Skipping invalid line: t	concert	virtuoso	6.81
# Skipping invalid line: S	rock	jazz	7.59
# Skipping invalid line: S	museum	theater	7.19
# Skipping invalid line: t	observation	architecture	4.38
# Skipping invalid line: t	space	world	6.53
# Skipping invalid line: t	preservation	world	6.19
# Skipping invalid line: t	admission	ticket	7.69
# Skipping invalid line: S	shower	thunderstorm	6.31
# Skipping invalid line: t	shower	flood	6.03
# Skipping invalid line: t	weather	forecast	8.34
# Skipping invalid line: t	disaster	area	6.25
# Skipping invalid line: t	governor	office	6.34
# Skipping invalid line: t	architecture	century	3.78
# Skipping invalid line: #Word 1	Word 2	Human (mean)
# Skipping invalid line: # i = identical tokens
# Skipping invalid line: # s = synonym (at least in one meaning of each)
# Skipping invalid line: # h = first is hyponym of second (at least in one meaning of each)
# Skipping invalid line: # H = first is hyperonym of second (at least in one meaning of each)
# Skipping invalid line: # S = sibling terms (terms with a common hyperonymy)
# Skipping invalid line: # m = first is part of the second one (at least in one meaning of each)
# Skipping invalid line: # M = second is part of the first one (at least in one meaning of each)
# Skipping invalid line: # t = topically related, but none of the above
# Skipping invalid line: #
# Skipping invalid line: s	love	sex	6.77
# Skipping invalid line: S	tiger	cat	7.35
# Skipping invalid line: i	tiger	tiger	10.00
# Skipping invalid line: t	book	paper	7.46
# Skipping invalid line: M	computer	keyboard	7.62
# Skipping invalid line: t	computer	internet	7.58
# Skipping invalid line: S	plane	car	5.77
# Skipping invalid line: S	train	car	6.31
# Skipping invalid line: t	telephone	communication	7.50
# Skipping invalid line: S	television	radio	6.77
# Skipping invalid line: H	media	radio	7.42
# Skipping invalid line: t	drug	abuse	6.85
# Skipping invalid line: S	bread	butter	6.19
# Skipping invalid line: S	cucumber	potato	5.92
# Skipping invalid line: t	doctor	nurse	7.00
# Skipping invalid line: s	professor	doctor	6.62
# Skipping invalid line: S	student	professor	6.81
# Skipping invalid line: t	smart	student	4.62
# Skipping invalid line: S	smart	stupid	5.81
# Skipping invalid line: t	company	stock	7.08
# Skipping invalid line: s	stock	market	8.08
# Skipping invalid line: t	stock	phone	1.62
# Skipping invalid line: t	stock	CD	1.31
# Skipping invalid line: t	stock	jaguar	0.92
# Skipping invalid line: t	stock	egg	1.81
# Skipping invalid line: t	fertility	egg	6.69
# Skipping invalid line: t	stock	live	3.73
# Skipping invalid line: t	stock	life	0.92
# Skipping invalid line: t	book	library	7.46
# Skipping invalid line: t	bank	money	8.12
# Skipping invalid line: s	wood	forest	7.73
# Skipping invalid line: s	money	cash	9.15
# Skipping invalid line: t	professor	cucumber	0.31
# Skipping invalid line: t	king	cabbage	0.23
# Skipping invalid line: S	king	queen	8.58
# Skipping invalid line: S	king	rook	5.92
# Skipping invalid line: S	bishop	rabbi	6.69
# Skipping invalid line: S	Jerusalem	Israel	8.46
# Skipping invalid line: t	Jerusalem	Palestinian	7.65
# Skipping invalid line: t	holy	sex	1.62
# Skipping invalid line: s	fuck	sex	9.44
# Skipping invalid line: t	Maradona	football	8.62
# Skipping invalid line: s	football	soccer	9.03
# Skipping invalid line: S	football	basketball	6.81
# Skipping invalid line: S	football	tennis	6.63
# Skipping invalid line: t	tennis	racket	7.56
# Skipping invalid line: t	Arafat	peace	6.73
# Skipping invalid line: t	Arafat	terror	7.65
# Skipping invalid line: S	Arafat	Jackson	2.50
# Skipping invalid line: t	law	lawyer	8.38
# Skipping invalid line: t	movie	star	7.38
# Skipping invalid line: t	movie	popcorn	6.19
# Skipping invalid line: t	movie	critic	6.73
# Skipping invalid line: t	movie	theater	7.92
# Skipping invalid line: t	physics	proton	8.12
# Skipping invalid line: S	physics	chemistry	7.35
# Skipping invalid line: t	space	chemistry	4.88
# Skipping invalid line: t	alcohol	chemistry	5.54
# Skipping invalid line: S	vodka	gin	8.46
# Skipping invalid line: S	vodka	brandy	8.13
# Skipping invalid line: t	drink	car	3.04
# Skipping invalid line: t	drink	ear	1.31
# Skipping invalid line: t	drink	mouth	5.96
# Skipping invalid line: S	drink	eat	6.87
# Skipping invalid line: t	baby	mother	7.85
# Skipping invalid line: t	drink	mother	2.65
# Skipping invalid line: s	car	automobile	8.94
# Skipping invalid line: s	gem	jewel	8.96
# Skipping invalid line: s	journey	voyage	9.29
# Skipping invalid line: s	boy	lad	8.83
# Skipping invalid line: s	coast	shore	9.10
# Skipping invalid line: s	asylum	madhouse	8.87
# Skipping invalid line: s	magician	wizard	9.02
# Skipping invalid line: s	midday	noon	9.29
# Skipping invalid line: s	furnace	stove	8.79
# Skipping invalid line: H	food	fruit	7.52
# Skipping invalid line: H	bird	cock	7.10
# Skipping invalid line: H	bird	crane	7.38
# Skipping invalid line: t	tool	implement	6.46
# Skipping invalid line: t	brother	monk	6.27
# Skipping invalid line: t	crane	implement	2.69
# Skipping invalid line: t	lad	brother	4.46
# Skipping invalid line: t	journey	car	5.85
# Skipping invalid line: t	monk	oracle	5.00
# Skipping invalid line: t	cemetery	woodland	2.08
# Skipping invalid line: t	food	rooster	4.42
# Skipping invalid line: t	coast	hill	4.38
# Skipping invalid line: t	forest	graveyard	1.85
# Skipping invalid line: t	shore	woodland	3.08
# Skipping invalid line: t	monk	slave	0.92
# Skipping invalid line: t	coast	forest	3.15
# Skipping invalid line: t	lad	wizard	0.92
# Skipping invalid line: t	chord	smile	0.54
# Skipping invalid line: t	glass	magician	2.08
# Skipping invalid line: t	noon	string	0.54
# Skipping invalid line: t	rooster	voyage	0.62
# Skipping invalid line: H	money	dollar	8.42
# Skipping invalid line: S	money	currency	9.04
# Skipping invalid line: t	money	wealth	8.27
# Skipping invalid line: t	money	property	7.57
# Skipping invalid line: t	money	possession	7.29
# Skipping invalid line: t	money	bank	8.50
# Skipping invalid line: t	money	deposit	7.73
# Skipping invalid line: t	money	withdrawal	6.88
# Skipping invalid line: t	money	laundering	5.65
# Skipping invalid line: t	money	operation	3.31
# Skipping invalid line: S	tiger	jaguar	8.00
# Skipping invalid line: t	tiger	feline	8.00
# Skipping invalid line: h	tiger	carnivore	7.08
# Skipping invalid line: h	tiger	mammal	6.85
# Skipping invalid line: h	tiger	animal	7.00
# Skipping invalid line: h	tiger	organism	4.77
# Skipping invalid line: h	tiger	fauna	5.62
# Skipping invalid line: t	tiger	zoo	5.87
# Skipping invalid line: t	psychology	psychiatry	8.08
# Skipping invalid line: t	psychology	anxiety	7.00
# Skipping invalid line: t	psychology	fear	6.85
# Skipping invalid line: t	psychology	depression	7.42
# Skipping invalid line: t	psychology	clinic	6.58
# Skipping invalid line: t	psychology	doctor	6.42
# Skipping invalid line: t	psychology	Freud	8.21
# Skipping invalid line: t	psychology	mind	7.69
# Skipping invalid line: t	psychology	health	7.23
# Skipping invalid line: t	psychology	science	6.71
# Skipping invalid line: h	psychology	discipline	5.58
# Skipping invalid line: t	psychology	cognition	7.48
# Skipping invalid line: S	planet	star	8.45
# Skipping invalid line: t	planet	constellation	8.06
# Skipping invalid line: S	planet	moon	8.08
# Skipping invalid line: S	planet	sun	8.02
# Skipping invalid line: m	planet	galaxy	8.11
# Skipping invalid line: m	planet	space	7.92
# Skipping invalid line: t	planet	astronomer	7.94
# Skipping invalid line: t	precedent	example	5.85
# Skipping invalid line: t	precedent	information	3.85
# Skipping invalid line: t	precedent	cognition	2.81
# Skipping invalid line: t	precedent	law	6.65
# Skipping invalid line: t	precedent	collection	2.50
# Skipping invalid line: t	precedent	group	1.77
# Skipping invalid line: S	precedent	antecedent	6.04
# Skipping invalid line: t	cup	coffee	6.58
# Skipping invalid line: t	cup	tableware	6.85
# Skipping invalid line: t	cup	article	2.40
# Skipping invalid line: h	cup	artifact	2.92
# Skipping invalid line: h	cup	object	3.69
# Skipping invalid line: h	cup	entity	2.15
# Skipping invalid line: t	cup	drink	7.25
# Skipping invalid line: t	cup	food	5.00
# Skipping invalid line: t	cup	substance	1.92
# Skipping invalid line: t	cup	liquid	5.90
# Skipping invalid line: h	jaguar	cat	7.42
# Skipping invalid line: h	jaguar	car	7.27
# Skipping invalid line: t	energy	secretary	1.81
# Skipping invalid line: t	secretary	senate	5.06
# Skipping invalid line: t	energy	laboratory	5.09
# Skipping invalid line: t	computer	laboratory	6.78
# Skipping invalid line: t	weapon	secret	6.06
# Skipping invalid line: t	FBI	fingerprint	6.94
# Skipping invalid line: t	FBI	investigation	8.31
# Skipping invalid line: s	investigation	effort	4.59
# Skipping invalid line: t	Mars	water	2.94
# Skipping invalid line: t	Mars	scientist	5.63
# Skipping invalid line: s	news	report	8.16
# Skipping invalid line: h	canyon	landscape	7.53
# Skipping invalid line: t	image	surface	4.56
# Skipping invalid line: t	discovery	space	6.34
# Skipping invalid line: t	water	seepage	6.56
# Skipping invalid line: t	sign	recess	2.38
# Skipping invalid line: t	Wednesday	news	2.22
# Skipping invalid line: S	mile	kilometer	8.66
# Skipping invalid line: t	computer	news	4.47
# Skipping invalid line: t	territory	surface	5.34
# Skipping invalid line: t	atmosphere	landscape	3.69
# Skipping invalid line: t	president	medal	3.00
# Skipping invalid line: t	war	troops	8.13
# Skipping invalid line: t	record	number	6.31
# Skipping invalid line: S	skin	eye	6.22
# Skipping invalid line: S	Japanese	American	6.50
# Skipping invalid line: t	theater	history	3.91
# Skipping invalid line: t	volunteer	motto	2.56
# Skipping invalid line: t	prejudice	recognition	3.00
# Skipping invalid line: t	decoration	valor	5.63
# Skipping invalid line: S	century	year	7.59
# Skipping invalid line: t	century	nation	3.16
# Skipping invalid line: t	delay	racism	1.19
# Skipping invalid line: t	delay	news	3.31
# Skipping invalid line: t	minister	party	6.63
# Skipping invalid line: t	peace	plan	4.75
# Skipping invalid line: t	minority	peace	3.69
# Skipping invalid line: t	attempt	peace	4.25
# Skipping invalid line: t	government	crisis	6.56
# Skipping invalid line: t	deployment	departure	4.25
# Skipping invalid line: t	deployment	withdrawal	5.88
# Skipping invalid line: t	energy	crisis	5.94
# Skipping invalid line: s	announcement	news	7.56
# Skipping invalid line: t	announcement	effort	2.75
# Skipping invalid line: t	stroke	hospital	7.03
# Skipping invalid line: t	disability	death	5.47
# Skipping invalid line: t	victim	emergency	6.47
# Skipping invalid line: t	treatment	recovery	7.91
# Skipping invalid line: t	journal	association	4.97
# Skipping invalid line: t	doctor	personnel	5.00
# Skipping invalid line: t	doctor	liability	5.19
# Skipping invalid line: t	liability	insurance	7.03
# Skipping invalid line: t	school	center	3.44
# Skipping invalid line: t	reason	hypertension	2.31
# Skipping invalid line: t	reason	criterion	5.91
# Skipping invalid line: t	hundred	percent	7.38
# Skipping invalid line: S	Harvard	Yale	8.13
# Skipping invalid line: h	hospital	infrastructure	4.63
# Skipping invalid line: t	death	row	5.25
# Skipping invalid line: t	death	inmate	5.03
# Skipping invalid line: t	lawyer	evidence	6.69
# Skipping invalid line: S	life	death	7.88
# Skipping invalid line: t	life	term	4.50
# Skipping invalid line: t	word	similarity	4.75
# Skipping invalid line: t	board	recommendation	4.47
# Skipping invalid line: t	governor	interview	3.25
# Skipping invalid line: t	OPEC	country	5.63
# Skipping invalid line: t	peace	atmosphere	3.69
# Skipping invalid line: t	peace	insurance	2.94
# Skipping invalid line: S	territory	kilometer	5.28
# Skipping invalid line: h	travel	activity	5.00
# Skipping invalid line: t	competition	price	6.44
# Skipping invalid line: t	consumer	confidence	4.13
# Skipping invalid line: t	consumer	energy	4.75
# Skipping invalid line: t	problem	airport	2.38
# Skipping invalid line: t	car	flight	4.94
# Skipping invalid line: t	credit	card	8.06
# Skipping invalid line: t	credit	information	5.31
# Skipping invalid line: t	hotel	reservation	8.03
# Skipping invalid line: t	grocery	money	5.94
# Skipping invalid line: s	registration	arrangement	6.00
# Skipping invalid line: t	arrangement	accommodation	5.41
# Skipping invalid line: t	month	hotel	1.81
# Skipping invalid line: s	type	kind	8.97
# Skipping invalid line: t	arrival	hotel	6.00
# Skipping invalid line: t	bed	closet	6.72
# Skipping invalid line: t	closet	clothes	8.00
# Skipping invalid line: t	situation	conclusion	4.81
# Skipping invalid line: t	situation	isolation	3.88
# Skipping invalid line: t	impartiality	interest	5.16
# Skipping invalid line: t	direction	combination	2.25
# Skipping invalid line: h	street	place	6.44
# Skipping invalid line: s	street	avenue	8.88
# Skipping invalid line: S	street	block	6.88
# Skipping invalid line: t	street	children	4.94
# Skipping invalid line: t	listing	proximity	2.56
# Skipping invalid line: t	listing	category	6.38
# Skipping invalid line: s	cell	phone	7.81
# Skipping invalid line: t	production	hike	1.75
# Skipping invalid line: t	benchmark	index	4.25
# Skipping invalid line: t	media	trading	3.88
# Skipping invalid line: t	media	gain	2.88
# Skipping invalid line: s	dividend	payment	7.63
# Skipping invalid line: t	dividend	calculation	6.48
# Skipping invalid line: s	calculation	computation	8.44
# Skipping invalid line: t	currency	market	7.50
# Skipping invalid line: t	OPEC	oil	8.59
# Skipping invalid line: t	oil	stock	6.34
# Skipping invalid line: t	announcement	production	3.38
# Skipping invalid line: t	announcement	warning	6.00
# Skipping invalid line: t	profit	warning	3.88
# Skipping invalid line: S	profit	loss	7.63
# Skipping invalid line: S	dollar	yen	7.78
# Skipping invalid line: s	dollar	buck	9.22
# Skipping invalid line: t	dollar	profit	7.38
# Skipping invalid line: t	dollar	loss	6.09
# Skipping invalid line: M	computer	software	8.50
# Skipping invalid line: S	network	hardware	8.31
# Skipping invalid line: h	phone	equipment	7.13
# Skipping invalid line: H	equipment	maker	5.91
# Skipping invalid line: t	luxury	car	6.47
# Skipping invalid line: t	five	month	3.38
# Skipping invalid line: t	report	gain	3.63
# Skipping invalid line: t	investor	earning	7.13
# Skipping invalid line: H	liquid	water	7.89
# Skipping invalid line: t	baseball	season	5.97
# Skipping invalid line: t	game	victory	7.03
# Skipping invalid line: t	game	team	7.69
# Skipping invalid line: S	marathon	sprint	7.47
# Skipping invalid line: t	game	series	6.19
# Skipping invalid line: t	game	defeat	6.97
# Skipping invalid line: t	seven	series	3.56
# Skipping invalid line: t	seafood	sea	7.47
# Skipping invalid line: h	seafood	food	8.34
# Skipping invalid line: H	seafood	lobster	8.70
# Skipping invalid line: h	lobster	food	7.81
# Skipping invalid line: S	lobster	wine	5.70
# Skipping invalid line: t	food	preparation	6.22
# Skipping invalid line: t	video	archive	6.34
# Skipping invalid line: t	start	year	4.06
# Skipping invalid line: t	start	match	4.47
# Skipping invalid line: t	game	round	5.97
# Skipping invalid line: t	boxing	round	7.61
# Skipping invalid line: s	championship	tournament	8.36
# Skipping invalid line: t	fighting	defeating	7.41
# Skipping invalid line: t	line	insurance	2.69
# Skipping invalid line: t	day	summer	3.94
# Skipping invalid line: t	summer	drought	7.16
# Skipping invalid line: t	summer	nature	5.63
# Skipping invalid line: t	day	dawn	7.53
# Skipping invalid line: s	nature	environment	8.31
# Skipping invalid line: t	environment	ecology	8.81
# Skipping invalid line: t	nature	man	6.25
# Skipping invalid line: S	man	woman	8.30
# Skipping invalid line: t	man	governor	5.25
# Skipping invalid line: s	murder	manslaughter	8.53
# Skipping invalid line: t	soap	opera	7.94
# Skipping invalid line: h	opera	performance	6.88
# Skipping invalid line: t	life	lesson	5.94
# Skipping invalid line: t	focus	life	4.06
# Skipping invalid line: t	production	crew	6.25
# Skipping invalid line: t	television	film	7.72
# Skipping invalid line: t	lover	quarrel	6.19
# Skipping invalid line: t	viewer	serial	2.97
# Skipping invalid line: t	possibility	girl	1.94
# Skipping invalid line: t	population	development	3.75
# Skipping invalid line: t	morality	importance	3.31
# Skipping invalid line: t	morality	marriage	3.69
# Skipping invalid line: S	Mexico	Brazil	7.44
# Skipping invalid line: t	gender	equality	6.41
# Skipping invalid line: t	change	attitude	5.44
# Skipping invalid line: t	family	planning	6.25
# Skipping invalid line: t	opera	industry	2.63
# Skipping invalid line: t	sugar	approach	0.88
# Skipping invalid line: t	practice	institution	3.19
# Skipping invalid line: t	ministry	culture	4.69
# Skipping invalid line: t	problem	challenge	6.75
# Skipping invalid line: t	size	prominence	5.31
# Skipping invalid line: m	country	citizen	7.31
# Skipping invalid line: m	planet	people	5.75
# Skipping invalid line: t	development	issue	3.97
# Skipping invalid line: t	experience	music	3.47
# Skipping invalid line: t	music	project	3.63
# Skipping invalid line: S	glass	metal	5.56
# Skipping invalid line: h	aluminum	metal	7.83
# Skipping invalid line: t	chance	credibility	3.88
# Skipping invalid line: t	exhibit	memorabilia	5.31
# Skipping invalid line: t	concert	virtuoso	6.81
# Skipping invalid line: S	rock	jazz	7.59
# Skipping invalid line: S	museum	theater	7.19
# Skipping invalid line: t	observation	architecture	4.38
# Skipping invalid line: t	space	world	6.53
# Skipping invalid line: t	preservation	world	6.19
# Skipping invalid line: t	admission	ticket	7.69
# Skipping invalid line: S	shower	thunderstorm	6.31
# Skipping invalid line: t	shower	flood	6.03
# Skipping invalid line: t	weather	forecast	8.34
# Skipping invalid line: t	disaster	area	6.25
# Skipping invalid line: t	governor	office	6.34
# Skipping invalid line: t	architecture	century	3.78
# Mean Squared Error: 28.035796772323245
# Spearman Correlation: 0.481987981608143
