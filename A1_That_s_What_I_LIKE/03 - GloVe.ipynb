# %%
import nltk
# nltk.download()

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Define some very simple data for understanding

# %%
from nltk.corpus import brown

# Fetch sentences from the 'news' category of the Brown corpus
corpus = brown.sents(categories='news') 

# Convert sentences into a list of words for each sentence
corpus = [[word for word in sentence] for sentence in corpus]

# Print the first sentence as a list of words
print(corpus[0])
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.']

# %%
#get word sequences and unique words
flatten = lambda l: [item for sublist in l for item in sublist]
vocab = list(set(flatten(corpus)))

vocab
# Out:
# ['canted',
#  'Georgetown',
#  'plate',
#  'Coronado',
#  'Exposition',
#  'Carnival',
#  'classmates',
#  'exert',
#  'claims',
#  'Testament',
#  'keeps',
#  'Francis',
#  'imminent',
#  'Corporation',
#  'irritable',
#  'Studio',
#  'figured',
#  'pair',
#  'ill',
#  'Apartment',
#  'Waddell',
#  'advocate',
#  'subscribe',
#  'just',
#  'confirmation',
#  'Mortgage',
#  'all-important',
#  'glanced',
#  'lively',
#  'O-B',
#  'decolletage',
#  'extensive',
#  'knocks',
#  'Coach',
#  'tight',
#  'within',
#  'fit',
#  'Peterson',
#  'respected',
#  'occasional',
#  'Senators',
#  'Omega',
#  'Policies',
#  'extending',
#  'redistricting',
#  'diamond',
#  'Rowley',
#  'jump',
#  'sixth',
#  'saluted',
#  'sponsored',
#  'excellence',
#  'enactment',
#  'monumental',
#  'capers',
#  'wallet',
#  'selfish',
#  'fitted',
#  'cleaners',
#  'reviewing',
#  'appliques',
#  'miss',
#  '$80,738',
#  "we'll",
#  'image',
#  'skip',
#  'hoodlum',
#  'worship',
#  'co-operation',
#  'Shay',
#  'assistance',
#  'member',
#  'play',
#  'reproductions',
#  'half-brothers',
#  'against',
#  "Europe's",
#  'neutral',
#  'urgency',
#  'compiled',
#  '$12,500',
#  '2-hour-and-27-minute',
#  'Rostagnos',
#  'finds',
#  'Epstein',
#  'sculptured',
#  'Danger',
#  'rides',
#  'Usually',
#  'sumptuous',
#  'defend',
#  'Kankakee',
#  'toneless',
#  'timely',
#  'embezzlement',
#  'nightly',
#  'Sopsaisana',
#  'Anywhere',
#  '1930s',
#  'manager',
#  'quit',
#  'unlike',
#  'Christian',
#  'reasons',
#  'Serra',
#  'helm',
#  'derive',
#  'presidential',
#  'finalist',
#  'batters',
#  'explosion',
#  'endangering',
#  'ASDIC',
#  'Officials',
#  'de',
#  'perjury',
#  'arson',
#  "Here's",
#  'buildings',
#  'Registrations',
#  'Crosby',
#  'diversified',
#  'periodicals',
#  'tickets',
#  'jazz',
#  'Hugh',
#  'defense',
#  'aptly',
#  'wall-to-wall',
#  'Inauguration',
#  'acceptance',
#  'instead',
#  '61',
#  'mid-July',
#  '$4,800',
#  'Sabol',
#  'clay',
#  'significant',
#  'attraction',
#  'boost',
#  'separators',
#  'speed',
#  'aeronautical',
#  'Delahanty',
#  'grass',
#  'Tower',
#  'canvass',
#  'filled',
#  'fame',
#  'Carlson',
#  'programmed',
#  'Emma',
#  'Indications',
#  'Dyer',
#  'exercise',
#  'Loewe',
#  'Attorney',
#  'subsequent',
#  'loaded',
#  'Women',
#  'Hodges',
#  'sort',
#  'incredible',
#  'Actor-Crooner',
#  "Underwood's",
#  'juvenile',
#  'Noted',
#  'tensions',
#  'Steelers',
#  'bounty',
#  'Between',
#  '185,000',
#  "Bros.'",
#  'tired',
#  'villa',
#  'worsens',
#  'Gloriana',
#  'truths',
#  '1958-60',
#  'statement',
#  'fun',
#  'entertain',
#  'Contemporary',
#  'serene',
#  'Judith',
#  'Island',
#  'decency',
#  'breed',
#  'Banks',
#  'genuine',
#  'Heights',
#  "U.N.'s",
#  'bloc',
#  'Prize',
#  'Huddle',
#  'anti-Negro',
#  'In',
#  'Swelling',
#  'pepper',
#  'strongly',
#  'hate',
#  "aren't",
#  'tagged',
#  'little',
#  '3-0',
#  'conversions',
#  'newsman',
#  'dogleg',
#  'stevedore',
#  'makers',
#  'giveaway',
#  'Joey',
#  "University's",
#  'generally',
#  'visit',
#  'Norway',
#  'full-fledged',
#  'Palo',
#  'Mandarin',
#  'Branum',
#  'photographers',
#  '2.325%',
#  '2274',
#  'elements',
#  'greeting',
#  'enforce',
#  'also',
#  'represented',
#  'Fairy',
#  'scoreboards',
#  'surge',
#  'refuel',
#  'determination',
#  'story',
#  'Travelers',
#  'Vinson',
#  'escaping',
#  'renting',
#  'prospects',
#  'pubs',
#  'Kriss',
#  'Leighton',
#  'Arranging',
#  'DiSimone',
#  "hemisphere's",
#  'National',
#  'Three',
#  'dot',
#  'film',
#  'Burke',
#  "Texas'",
#  'picketing',
#  'contacted',
#  'shelves',
#  'toss',
#  'Michaels',
#  'test',
#  'Darrow',
#  'Attitude',
#  'bellboys',
#  'manuscript',
#  'facto',
#  'Week',
#  'responsible',
#  'slowly',
#  'notable',
#  'violated',
#  'NBC',
#  'envisioned',
#  'wilderness',
#  'researchers',
#  'trading',
#  'explain',
#  'Shore',
#  'drums',
#  'orderly',
#  'congressional',
#  'bottled',
#  'Strenuous',
#  'Heitschmidt',
#  'irrationality',
#  'much',
#  'hazards',
#  'Longhorn',
#  'hardware',
#  'antiquarians',
#  'Ludwig',
#  'chopper',
#  'Inna',
#  'stayed',
#  'Lyon',
#  'recipients',
#  "U.'s",
#  'presentation',
#  'ex-gambler',
#  '1215',
#  'Mack',
#  'Growth',
#  'innings',
#  'down-payments',
#  'Jamaica',
#  'affects',
#  'criticisms',
#  'Danbury',
#  'Republicans',
#  'mentally',
#  'Governor',
#  'monthly',
#  'mammoth',
#  'Wiley',
#  'masonry',
#  'Luette',
#  'operator',
#  'cobalt',
#  'Virdon',
#  'get-together',
#  'relentlessly',
#  'tapestry',
#  "Jorda's",
#  'moments',
#  'thinks',
#  'muster',
#  'session',
#  "Commissioner's",
#  '95',
#  'Kansas',
#  'Its',
#  'ashes',
#  'unfortunately',
#  'phrase',
#  'smelling',
#  'teen-age',
#  '17',
#  'hooked',
#  'Such',
#  'Hatfield',
#  'tape',
#  'human',
#  'still',
#  'Shoup',
#  'tenths',
#  'withdrawal',
#  'Ilona',
#  'Savannah',
#  'Parmer',
#  'paired',
#  'lies',
#  'lower',
#  'surprise',
#  'watching',
#  'makeshift',
#  'considered',
#  'passed',
#  '$2,170',
#  'destined',
#  'superintendent',
#  'collects',
#  'injunctions',
#  'Rookie',
#  'rejection',
#  'hailed',
#  'earliest',
#  'vacated',
#  "Gardner's",
#  'county-wide',
#  'home-run',
#  'club',
#  '64-cent',
#  'Mmes.',
#  'quest',
#  'garrulous',
#  'expectations',
#  'con',
#  'endowment',
#  'copies',
#  'smuggling',
#  "golf's",
#  'guidance',
#  'Schmalzried',
#  'began',
#  'fairways',
#  'governor',
#  'ex-Yankee',
#  'converted',
#  'community',
#  'cities',
#  'elder',
#  '23',
#  'acts',
#  'Tex.',
#  'style',
#  'Emmert',
#  "mechanic's",
#  "management's",
#  'investigation',
#  'assumed',
#  'fondness',
#  'Thruston',
#  'commodities',
#  'lighter',
#  'bulletins',
#  'elite',
#  'Barker',
#  '380-foot',
#  'count',
#  'Ambulances',
#  'corporate',
#  'steaming',
#  'blue',
#  'grain',
#  'Rae',
#  'receiving',
#  'Izvestia',
#  'generously',
#  'leader',
#  'Seattle',
#  'Marv',
#  'Harvester',
#  'frock',
#  'politely',
#  'moved',
#  'debutante',
#  'Cooperman',
#  'northern',
#  'unlikely',
#  'Parrillo',
#  'Kloman',
#  'Nakoma',
#  'exclusive',
#  "1800's",
#  'flooded',
#  'Garland',
#  'Olympic',
#  'Jenkins',
#  'exhibited',
#  'Arrow',
#  'flicker',
#  'wooden',
#  'subsequently',
#  'Theatre',
#  'capture',
#  'specifications',
#  'Net',
#  'cream',
#  'manganese',
#  'runway',
#  'destroy',
#  'expand',
#  'Ticker',
#  'unique',
#  'plea',
#  '7034',
#  'penalized',
#  'Achaeans',
#  'sadism',
#  'chatte',
#  'subdued',
#  'investigating',
#  'Dresbachs',
#  'Kalonji',
#  '30,000',
#  'as',
#  'Asilomar',
#  'Split',
#  '$5,000',
#  'appointments',
#  'Brocklin',
#  'halftime',
#  'oust',
#  'start',
#  'Santa',
#  'Willy',
#  "d'hotel",
#  'points',
#  'discharging',
#  'magic',
#  "Hutchins'",
#  'parade',
#  '25,000,000',
#  'statues',
#  '$15,000',
#  'weaken',
#  'lady',
#  'afford',
#  'Grady',
#  'disillusioned',
#  'Supt.',
#  '7',
#  'How',
#  'Northwestern',
#  'regulating',
#  '9th',
#  'constructive',
#  'fees',
#  '1213-15',
#  'chestnut',
#  'Oslo',
#  'Among',
#  'lefthander',
#  'plates',
#  'realistic',
#  'undetermined',
#  'quarter-to-quarter',
#  'Funds',
#  'Breeding',
#  'E.O.',
#  'crew',
#  'literature',
#  'Taking',
#  'park',
#  '$32,000',
#  'scholarships',
#  'democratic',
#  'recently',
#  'inherent',
#  'lobby',
#  'Blyth',
#  'comprised',
#  'finals',
#  'anti-submarine',
#  'adjourned',
#  'passengers',
#  'Lawn',
#  'leaders',
#  'crises',
#  'Forest',
#  'onion',
#  'collapsed',
#  'trim',
#  'battling',
#  'to',
#  'profits',
#  'Cacophonist',
#  'bath',
#  '129%',
#  'majority',
#  'biennial',
#  'blunders',
#  'Berlin',
#  'considerably',
#  'Fifteen',
#  '80',
#  'Malone',
#  'N.C.',
#  'competition',
#  'summed',
#  'Elios',
#  'halt',
#  'daylight',
#  'acacia',
#  'surveillance',
#  'workout',
#  'hitch',
#  'unified',
#  'dreadful',
#  'instances',
#  'he',
#  'associates',
#  'Shrine',
#  'erroneous',
#  'barrage',
#  'inside',
#  'Birgit',
#  'Campus',
#  'miscalculation',
#  'Momentarily',
#  '$451,500',
#  'Passage',
#  'shops',
#  'Crump',
#  'rested',
#  'Jessy',
#  'lamp',
#  'parklike',
#  'speeding',
#  'Leland',
#  'ex-schoolteacher',
#  'champions',
#  'Mansion',
#  'sheriff',
#  'rising',
#  'die',
#  'cerebrated',
#  'eased',
#  'Exclaimed',
#  'Lint',
#  'Foundation',
#  'challenging',
#  '330',
#  'clearance',
#  'pulling',
#  'beaten',
#  'entomologist',
#  'suggested',
#  'rangy',
#  'stag',
#  'radical',
#  'Ex-Oriole',
#  'cook',
#  'policy',
#  'Pp.',
#  'ivory',
#  'Cervetto',
#  'steel',
#  'Bali',
#  'Legislators',
#  'underestimate',
#  'letters',
#  'assemblage',
#  '14-power',
#  'adjust',
#  'violent',
#  'Sorrentino',
#  'somebody',
#  'under',
#  'piping',
#  'numbers',
#  'anti-monopoly',
#  'leadership',
#  'Justice',
#  'whirling',
#  'dismiss',
#  "Castro's",
#  '$120',
#  'celebrating',
#  'Phouma',
#  '12-year-old',
#  'reduced',
#  'tasks',
#  'teamsters',
#  'hard-to-get',
#  'great',
#  'survival',
#  'subsidized',
#  'idols',
#  'proceeded',
#  'body',
#  'satisfying',
#  'components',
#  'Ballet',
#  "Raphael's",
#  'Bleckley',
#  'Murphy',
#  'Squeezed',
#  'mutual',
#  'route',
#  'else',
#  'anywhere',
#  'Leo',
#  'currently',
#  'responded',
#  'me',
#  'Principal',
#  '1924',
#  'scientific',
#  'Viet',
#  'Wingback',
#  'era',
#  'increasingly',
#  'Terral',
#  '100%',
#  'Italian',
#  'driver',
#  "Portland's",
#  'dazzler',
#  'noticeable',
#  'build',
#  'Tennis',
#  'camping-out',
#  'Cain',
#  'McIntyre',
#  'originally',
#  'aerial',
#  'doorman',
#  'account',
#  'Harlingen',
#  'changing',
#  'unusual',
#  'maverick',
#  'adoption',
#  'whereby',
#  'distinctly',
#  'tore',
#  'Life',
#  'midway',
#  'Bruce',
#  'Marr',
#  'clamoring',
#  '$2,330,000',
#  'delighted',
#  'Broadway',
#  'type',
#  'export',
#  '1940',
#  'Lucille',
#  'branches',
#  'couch',
#  '27',
#  'acreage',
#  'Town',
#  'handsome',
#  'innocence',
#  'banjo',
#  'rocket-bombs',
#  'motion-picture',
#  'Africa',
#  'hired',
#  'newest',
#  'notices',
#  'Olsen',
#  'final',
#  'Glen',
#  'birdies',
#  'Work',
#  'Bexar',
#  'drops',
#  'code',
#  'Cites',
#  'manifestations',
#  'presentments',
#  'leaked',
#  '6',
#  'tourists',
#  'Ideally',
#  'Bibb',
#  'epicure',
#  'apply',
#  'fund-raising',
#  'centuries',
#  'Fundamental',
#  'Frankie',
#  'advantage',
#  'Pablo',
#  'adjustment',
#  'manifestly',
#  'target',
#  'puts',
#  'amazing',
#  'million',
#  'Voters',
#  'Daily',
#  'Shelby',
#  'division',
#  'Morris',
#  'efficiently',
#  'household',
#  'single',
#  'presents',
#  'candidates',
#  'critic',
#  'windy',
#  'weaknesses',
#  "guide's",
#  'investigated',
#  'Drum',
#  "ruling's",
#  'Casals',
#  "Player's",
#  'ripped',
#  'exchange',
#  'Arkansas',
#  'Stranahan',
#  'tanks',
#  'compassion',
#  'Afterwards',
#  'serve',
#  'Trinity',
#  'membership',
#  'flow',
#  'models',
#  'money-winner',
#  'experienced',
#  'marginal',
#  'ask',
#  'Whelan',
#  'rendered',
#  'bipartisan',
#  'tracts',
#  'For',
#  'Wards',
#  'allowed',
#  'total',
#  'Bowman',
#  'statewide',
#  'older',
#  'Grant',
#  'brunches',
#  "Alusik's",
#  'voted',
#  'Elementary',
#  'tardiness',
#  'announcing',
#  'Monet',
#  '9,273',
#  'increasing',
#  'Nikita',
#  "Government's",
#  'friendly',
#  'charter',
#  'consulate',
#  'upturn',
#  'nodded',
#  'Hyannis',
#  'consists',
#  'propeller',
#  'alleged',
#  'chipped',
#  'Universal-International',
#  'home',
#  'proceeds',
#  'lad',
#  'Galt',
#  'managements',
#  'opposition',
#  'holes',
#  'Tranquility',
#  'business',
#  'submarine-ball',
#  'big-league',
#  "Smith's",
#  'Tuttle',
#  'Merritt',
#  'Epsilon',
#  'Sarkees',
#  'inhomogeneous',
#  'Laos',
#  'boomed',
#  '1859',
#  'obligated',
#  'familiar',
#  'No',
#  'feted',
#  'borders',
#  'giving',
#  'MacWhorter',
#  'drab',
#  'Republican-controlled',
#  'nicer',
#  'bodies',
#  'Frederic',
#  'Plus',
#  'seize',
#  '6th',
#  'Leaguers',
#  'import',
#  'Agriculture',
#  "Dealers'",
#  'Operating',
#  'earnest',
#  'Met',
#  'Prince',
#  'limitations',
#  'succeeded',
#  'sell',
#  'slip',
#  'fixed',
#  'Senese',
#  'Yes',
#  'inherited',
#  'slave',
#  'junior-senior',
#  'Alpharetta',
#  'Susan',
#  '2nd',
#  'attactive',
#  'Phyllis',
#  'equipped',
#  'Theater',
#  'Culmone',
#  'functionary',
#  'strings',
#  'marble',
#  'K.J.P.',
#  'Tax',
#  'Moultons',
#  'investor',
#  "Fardulli's",
#  'Business',
#  'firemen',
#  'Cincinnati',
#  'injured',
#  'one-week-old',
#  '30-30',
#  'thug',
#  'housewife',
#  'bull-necked',
#  'Clifton',
#  'Pirate',
#  'basic',
#  '40',
#  '56-yard',
#  'wailed',
#  'Braves',
#  'necessitate',
#  'exciting',
#  'wherever',
#  'concert',
#  'impossibly',
#  'Accardo',
#  '30,000,000',
#  'camp',
#  'battleground',
#  'advocating',
#  '357',
#  'Episcopal',
#  'urgent',
#  'beyond',
#  'rig',
#  'pressure',
#  'deeper',
#  'termed',
#  'Mining',
#  'colored',
#  '$3100',
#  'Webster',
#  'stoppage',
#  'Their',
#  'wheels',
#  'victory',
#  'fell',
#  'leads',
#  'Institute',
#  'Hartman',
#  'stronger',
#  'marketing',
#  'socks',
#  '47',
#  'Buffalo',
#  'sand',
#  'supervisors',
#  'pretext',
#  'Anna',
#  'data',
#  'Track',
#  'beef',
#  'Cologne',
#  '2809',
#  'Senator',
#  'march',
#  'raw',
#  'crossing',
#  'grow',
#  'pray',
#  'Calude',
#  'Chester',
#  'conducting',
#  'Double',
#  'severely',
#  'gravy',
#  'Opelika',
#  'precinct',
#  'App',
#  'Russ',
#  'Billy',
#  'House',
#  'Presidential',
#  'D.C.',
#  'polled',
#  'Hills',
#  'lay',
#  "'em",
#  'century',
#  'woods',
#  "that's",
#  '126',
#  'suitable',
#  'previous',
#  'Tulane',
#  'doubtless',
#  'capacity',
#  'grew',
#  'Henry',
#  'opened',
#  'handle',
#  'leisurely',
#  'in-group',
#  'Jody',
#  'street',
#  'procedure',
#  'tragedy',
#  'astray',
#  'married',
#  "o'clock",
#  'commission',
#  'tax',
#  'highs',
#  'enthusiasm',
#  'clobbers',
#  'Ullman',
#  'fair',
#  'Changes',
#  "Kirov's",
#  "Pentagon's",
#  'Mission',
#  'august',
#  "Kai-shek's",
#  'Cal.',
#  'Stickler',
#  'push',
#  'wiping',
#  ...]

# %%
#numericalization
word2index = {w: i for i, w in enumerate(vocab)}
print(word2index)
# Out:
# {'canted': 0, 'Georgetown': 1, 'plate': 2, 'Coronado': 3, 'Exposition': 4, 'Carnival': 5, 'classmates': 6, 'exert': 7, 'claims': 8, 'Testament': 9, 'keeps': 10, 'Francis': 11, 'imminent': 12, 'Corporation': 13, 'irritable': 14, 'Studio': 15, 'figured': 16, 'pair': 17, 'ill': 18, 'Apartment': 19, 'Waddell': 20, 'advocate': 21, 'subscribe': 22, 'just': 23, 'confirmation': 24, 'Mortgage': 25, 'all-important': 26, 'glanced': 27, 'lively': 28, 'O-B': 29, 'decolletage': 30, 'extensive': 31, 'knocks': 32, 'Coach': 33, 'tight': 34, 'within': 35, 'fit': 36, 'Peterson': 37, 'respected': 38, 'occasional': 39, 'Senators': 40, 'Omega': 41, 'Policies': 42, 'extending': 43, 'redistricting': 44, 'diamond': 45, 'Rowley': 46, 'jump': 47, 'sixth': 48, 'saluted': 49, 'sponsored': 50, 'excellence': 51, 'enactment': 52, 'monumental': 53, 'capers': 54, 'wallet': 55, 'selfish': 56, 'fitted': 57, 'cleaners': 58, 'reviewing': 59, 'appliques': 60, 'miss': 61, '$80,738': 62, "we'll": 63, 'image': 64, 'skip': 65, 'hoodlum': 66, 'worship': 67, 'co-operation': 68, 'Shay': 69, 'assistance': 70, 'member': 71, 'play': 72, 'reproductions': 73, 'half-brothers': 74, 'against': 75, "Europe's": 76, 'neutral': 77, 'urgency': 78, 'compiled': 79, '$12,500': 80, '2-hour-and-27-minute': 81, 'Rostagnos': 82, 'finds': 83, 'Epstein': 84, 'sculptured': 85, 'Danger': 86, 'rides': 87, 'Usually': 88, 'sumptuous': 89, 'defend': 90, 'Kankakee': 91, 'toneless': 92, 'timely': 93, 'embezzlement': 94, 'nightly': 95, 'Sopsaisana': 96, 'Anywhere': 97, '1930s': 98, 'manager': 99, 'quit': 100, 'unlike': 101, 'Christian': 102, 'reasons': 103, 'Serra': 104, 'helm': 105, 'derive': 106, 'presidential': 107, 'finalist': 108, 'batters': 109, 'explosion': 110, 'endangering': 111, 'ASDIC': 112, 'Officials': 113, 'de': 114, 'perjury': 115, 'arson': 116, "Here's": 117, 'buildings': 118, 'Registrations': 119, 'Crosby': 120, 'diversified': 121, 'periodicals': 122, 'tickets': 123, 'jazz': 124, 'Hugh': 125, 'defense': 126, 'aptly': 127, 'wall-to-wall': 128, 'Inauguration': 129, 'acceptance': 130, 'instead': 131, '61': 132, 'mid-July': 133, '$4,800': 134, 'Sabol': 135, 'clay': 136, 'significant': 137, 'attraction': 138, 'boost': 139, 'separators': 140, 'speed': 141, 'aeronautical': 142, 'Delahanty': 143, 'grass': 144, 'Tower': 145, 'canvass': 146, 'filled': 147, 'fame': 148, 'Carlson': 149, 'programmed': 150, 'Emma': 151, 'Indications': 152, 'Dyer': 153, 'exercise': 154, 'Loewe': 155, 'Attorney': 156, 'subsequent': 157, 'loaded': 158, 'Women': 159, 'Hodges': 160, 'sort': 161, 'incredible': 162, 'Actor-Crooner': 163, "Underwood's": 164, 'juvenile': 165, 'Noted': 166, 'tensions': 167, 'Steelers': 168, 'bounty': 169, 'Between': 170, '185,000': 171, "Bros.'": 172, 'tired': 173, 'villa': 174, 'worsens': 175, 'Gloriana': 176, 'truths': 177, '1958-60': 178, 'statement': 179, 'fun': 180, 'entertain': 181, 'Contemporary': 182, 'serene': 183, 'Judith': 184, 'Island': 185, 'decency': 186, 'breed': 187, 'Banks': 188, 'genuine': 189, 'Heights': 190, "U.N.'s": 191, 'bloc': 192, 'Prize': 193, 'Huddle': 194, 'anti-Negro': 195, 'In': 196, 'Swelling': 197, 'pepper': 198, 'strongly': 199, 'hate': 200, "aren't": 201, 'tagged': 202, 'little': 203, '3-0': 204, 'conversions': 205, 'newsman': 206, 'dogleg': 207, 'stevedore': 208, 'makers': 209, 'giveaway': 210, 'Joey': 211, "University's": 212, 'generally': 213, 'visit': 214, 'Norway': 215, 'full-fledged': 216, 'Palo': 217, 'Mandarin': 218, 'Branum': 219, 'photographers': 220, '2.325%': 221, '2274': 222, 'elements': 223, 'greeting': 224, 'enforce': 225, 'also': 226, 'represented': 227, 'Fairy': 228, 'scoreboards': 229, 'surge': 230, 'refuel': 231, 'determination': 232, 'story': 233, 'Travelers': 234, 'Vinson': 235, 'escaping': 236, 'renting': 237, 'prospects': 238, 'pubs': 239, 'Kriss': 240, 'Leighton': 241, 'Arranging': 242, 'DiSimone': 243, "hemisphere's": 244, 'National': 245, 'Three': 246, 'dot': 247, 'film': 248, 'Burke': 249, "Texas'": 250, 'picketing': 251, 'contacted ...

# %%
#vocab size
voc_size = len(vocab)
print(voc_size)
# Out:
# 14394

# %%
# append UNK
vocab.append('<UNK>')

# %%
vocab[-1:]
# Out:
# ['<UNK>']

# %%
word2index['<UNK>'] = 0

# %%
#just in case we need to use
index2word = {v:k for k, v in word2index.items()}

# %% [markdown]
# ## 2. Build Co-occurence Matrix X

# %% [markdown]
# Here, we need to count the co-occurence of two words given some window size.  We gonna use window size of 1.

# %%
from collections import Counter

X_i = Counter(flatten(corpus)) # X_i
X_i
# Out:
# Counter({'the': 5580,
#          ',': 5188,
#          '.': 4030,
#          'of': 2849,
#          'and': 2146,
#          'to': 2116,
#          'a': 1993,
#          'in': 1893,
#          'for': 943,
#          'The': 806,
#          'that': 802,
#          '``': 732,
#          'is': 732,
#          'was': 717,
#          "''": 702,
#          'on': 657,
#          'at': 598,
#          'with': 545,
#          'be': 526,
#          'by': 497,
#          'as': 481,
#          'he': 451,
#          'said': 402,
#          'his': 399,
#          'will': 389,
#          'it': 363,
#          'from': 344,
#          'are': 328,
#          ';': 314,
#          'an': 300,
#          'has': 300,
#          '--': 300,
#          'had': 279,
#          'who': 268,
#          'have': 265,
#          'not': 254,
#          'Mrs.': 253,
#          'were': 252,
#          'this': 250,
#          'which': 244,
#          'would': 244,
#          'their': 219,
#          'been': 212,
#          'they': 205,
#          'He': 191,
#          'one': 184,
#          'I': 179,
#          'but': 174,
#          'its': 174,
#          'or': 173,
#          ')': 171,
#          'more': 171,
#          'Mr.': 170,
#          '(': 168,
#          'up': 168,
#          'all': 163,
#          'out': 161,
#          'last': 161,
#          'two': 157,
#          'other': 149,
#          ':': 149,
#          'new': 148,
#          'first': 143,
#          'than': 138,
#          'year': 138,
#          'A': 137,
#          'about': 136,
#          'there': 131,
#          'when': 128,
#          'home': 127,
#          'after': 127,
#          'In': 127,
#          'also': 120,
#          'It': 115,
#          'over': 115,
#          'into': 114,
#          'no': 109,
#          'But': 109,
#          'made': 107,
#          'only': 103,
#          'her': 103,
#          'years': 102,
#          'time': 97,
#          'three': 97,
#          'them': 96,
#          'some': 95,
#          'can': 93,
#          'him': 93,
#          'New': 93,
#          'any': 90,
#          'state': 90,
#          '?': 90,
#          'President': 89,
#          'before': 86,
#          'week': 86,
#          'could': 86,
#          'under': 83,
#          'against': 78,
#          'we': 77,
#          'what': 76,
#          'now': 76,
#          'most': 74,
#          'if': 74,
#          'off': 73,
#          'four': 73,
#          'man': 72,
#          'House': 71,
#          'such': 70,
#          'This': 70,
#          'back': 69,
#          'members': 69,
#          'so': 67,
#          'here': 67,
#          'American': 67,
#          'may': 66,
#          'program': 66,
#          'work': 66,
#          'get': 66,
#          'Kennedy': 66,
#          'John': 65,
#          'school': 65,
#          'night': 64,
#          'did': 63,
#          'State': 63,
#          'do': 63,
#          'They': 62,
#          'meeting': 62,
#          'since': 61,
#          'per': 61,
#          'each': 61,
#          'day': 61,
#          'many': 60,
#          'these': 59,
#          'should': 59,
#          'where': 58,
#          'There': 58,
#          'U.S.': 58,
#          'those': 58,
#          'United': 58,
#          'both': 56,
#          'being': 56,
#          'then': 56,
#          'yesterday': 56,
#          'our': 55,
#          'you': 55,
#          'during': 55,
#          'through': 54,
#          'Monday': 54,
#          'tax': 53,
#          'told': 53,
#          'president': 53,
#          'even': 53,
#          'administration': 52,
#          'people': 52,
#          'high': 52,
#          'York': 52,
#          'today': 52,
#          'government': 52,
#          'cent': 51,
#          'public': 51,
#          'sales': 51,
#          'Sunday': 51,
#          'set': 51,
#          'because': 51,
#          'game': 51,
#          'must': 50,
#          'good': 50,
#          'down': 50,
#          'car': 50,
#          'city': 49,
#          'Dallas': 49,
#          'much': 49,
#          'without': 49,
#          'take': 48,
#          'Texas': 48,
#          'Washington': 48,
#          'took': 47,
#          '1': 47,
#          'system': 47,
#          'board': 47,
#          'between': 47,
#          'men': 47,
#          'Jr.': 46,
#          'like': 46,
#          "'": 46,
#          'Miss': 46,
#          'Mantle': 46,
#          'plan': 45,
#          'million': 45,
#          'got': 45,
#          'bill': 45,
#          'children': 45,
#          'jury': 44,
#          'City': 44,
#          'way': 44,
#          'well': 43,
#          'Tuesday': 43,
#          'make': 43,
#          'while': 43,
#          'season': 43,
#          'J.': 42,
#          '1961': 42,
#          'just': 42,
#          'Dr.': 42,
#          'University': 42,
#          'business': 42,
#          'St.': 42,
#          'months': 42,
#          'she': 42,
#          'company': 42,
#          'Palmer': 42,
#          'Friday': 41,
#          'held': 41,
#          'When': 41,
#          'go': 41,
#          'special': 41,
#          'five': 41,
#          'own': 41,
#          'family': 41,
#          'came': 41,
#          'play': 41,
#          'next': 40,
#          'expected': 40,
#          'White': 40,
#          'National': 40,
#          'And': 40,
#          'problem': 39,
#          'long': 39,
#          'local': 39,
#          'left': 39,
#          'another': 39,
#          'area': 39,
#          'S.': 39,
#          'election': 38,
#          'law': 38,
#          'might': 38,
#          'committee': 38,
#          'W.': 38,
#          'see': 38,
#          'days': 38,
#          'A.': 38,
#          'group': 38,
#          'big': 38,
#          'never': 38,
#          'States': 38,
#          'Laos': 38,
#          'early': 38,
#          'At': 38,
#          '!': 38,
#          '1960': 38,
#          'p.m.': 38,
#          'Committee': 37,
#          'announced': 37,
#          'James': 37,
#          'session': 37,
#          'however': 37,
#          'given': 37,
#          'Democratic': 37,
#          'too': 37,
#          'went': 37,
#          'schools': 37,
#          'called': 37,
#          '10': 37,
#          'service': 37,
#          'how': 37,
#          'world': 37,
#          'William': 36,
#          'As': 36,
#          'March': 36,
#          'still': 36,
#          'third': 36,
#          'case': 36,
#          'ago': 36,
#          'same': 36,
#          'Maris': 36,
#          'County': 35,
#          'federal': 35,
#          'wife': 35,
#          'run': 35,
#          'chairman': 35,
#          'past': 35,
#          'little': 35,
#          'young': 35,
#          'record': 35,
#          'member': 35,
#          'She': 35,
#          'second': 35,
#          'On': 34,
#          'E.': 34,
#          'top': 34,
#          'asked': 34,
#          'party': 34,
#          'several': 34,
#          'my': 34,
#          'later': 34,
#          '&': 34,
#          'along': 34,
#          'began': 34,
#          'hit': 34,
#          'received': 33,
#          'added': 33,
#          '2': 33,
#          'very': 33,
#          'pay': 33,
#          'annual': 33,
#          'right': 33,
#          'team': 33,
#          'Saturday': 33,
#          'ball': 33,
#          'interest': 32,
#          'number': 32,
#          'Senate': 32,
#          'give': 32,
#          'ever': 32,
#          'C.': 32,
#          'national': 32,
#          'month': 32,
#          'total': 32,
#          'B.': 31,
#          'education': 31,
#          'need': 31,
#          'firm': 31,
#          'police': 31,
#          'use': 31,
#          'part': 31,
#          'again': 31,
#          'come': 31,
#          'far': 31,
#          'show': 31,
#          'equipment': 31,
#          'library': 31,
#          'Congo': 31,
#          'Player': 31,
#          'laws': 30,
#          'result': 30,
#          'found': 30,
#          'present': 30,
#          'taken': 30,
#          'director': 30,
#          'issue': 30,
#          'help': 30,
#          'We': 30,
#          'eight': 30,
#          'few': 30,
#          'around': 30,
#          'military': 30,
#          'great': 30,
#          'industry': 30,
#          'runs': 30,
#          'end': 29,
#          'best': 29,
#          'general': 29,
#          'money': 29,
#          'court': 29,
#          'His': 29,
#          'bonds': 29,
#          'If': 29,
#          'One': 29,
#          'North': 29,
#          'foreign': 29,
#          'me': 29,
#          'start': 29,
#          'center': 29,
#          'late': 29,
#          'club': 29,
#          'Judge': 28,
#          'possible': 28,
#          'funds': 28,
#          'major': 28,
#          'Robert': 28,
#          'vote': 28,
#          'says': 28,
#          'better': 28,
#          'reported': 28,
#          'Co.': 28,
#          'staff': 28,
#          'Soviet': 28,
#          'countries': 28,
#          'Communist': 28,
#          'know': 28,
#          'until': 28,
#          'To': 28,
#          'university': 28,
#          'political': 27,
#          'together': 27,
#          'put': 27,
#          'former': 27,
#          'enough': 27,
#          'meet': 27,
#          'Richard': 27,
#          'H.': 27,
#          'small': 27,
#          'That': 27,
#          'think': 27,
#          'open': 27,
#          'May': 27,
#          'Court': 26,
#          'daughter': 26,
#          'county': 26,
#          'does': 26,
#          'house': 26,
#          '4': 26,
#          'project': 26,
#          'higher': 26,
#          'needed': 26,
#          'For': 26,
#          'Republican': 26,
#          'Club': 26,
#          'market': 26,
#          'place': 25,
#          'future': 25,
#          'fact': 25,
#          'L.': 25,
#          'making': 25,
#          'every': 25,
#          'paid': 25,
#          'aid': 25,
#          'report': 25,
#          'including': 25,
#          'series': 25,
#          '3': 25,
#          'large': 25,
#          'F.': 25,
#          'used': 25,
#          'weeks': 25,
#          'minutes': 25,
#          'Khrushchev': 25,
#          'Street': 25,
#          'single': 25,
#          'away': 25,
#          'won': 24,
#          'among': 24,
#          'provide': 24,
#          'office': 24,
#          'head': 24,
#          'earlier': 24,
#          'D.': 24,
#          'increase': 24,
#          'done': 24,
#          'support': 24,
#          'After': 24,
#          'real': 24,
#          'persons': 24,
#          'almost': 24,
#          'decided': 24,
#          'Bill': 24,
#          'able': 24,
#          'six': 24,
#          '20': 24,
#          'field': 24,
#          'conference': 24,
#          'country': 24,
#          'course': 24,
#          'British': 24,
#          'collection': 24,
#          'upon': 23,
#          'according': 23,
#          'become': 23,
#          'toward': 23,
#          'old': 23,
#          'George': 23,
#          'League': 23,
#          'final': 23,
#          'effort': 23,
#          'say': 23,
#          'statement': 23,
#          'international': 23,
#          'labor': 23,
#          'victory': 23,
#          'Portland': 23,
#          'dinner': 23,
#          'Yankees': 23,
#          'baseball': 23,
#          'Catholic': 23,
#          'son': 22,
#          'M.': 22,
#          'Wednesday': 22,
#          '8': 22,
#          'plans': 22,
#          'Charles': 22,
#          'Hughes': 22,
#          'Jones': 22,
#          'School': 22,
#          'San': 22,
#          'West': 22,
#          'hours': 22,
#          'matter': 22,
#          'states': 22,
#          'going': 22,
#          'leader': 22,
#          'policy': 22,
#          'gave': 22,
#          'control': 22,
#          'efforts': 22,
#          'point': 22,
#          'leaders': 22,
#          'whose': 22,
#          'U.': 22,
#          'With': 22,
#          'Bob': 22,
#          'games': 22,
#          'yards': 22,
#          'Chicago': 22,
#          'libraries': 22,
#          'fire': 21,
#          'Hospital': 21,
#          'brought': 21,
#          'resolution': 21,
#          'Congress': 21,
#          'himself': 21,
#          'students': 21,
#          '12': 21,
#          'community': 21,
#          'trial': 21,
#          'tomorrow': 21,
#          'billion': 21,
#          'Secretary': 21,
#          'period': 21,
#          '1959': 21,
#          'income': 21,
#          'Thomas': 21,
#          'Government': 21,
#          'union': 21,
#          'Smith': 21,
#          'farm': 21,
#          'stock': 21,
#          'anti-trust': 21,
#          'recent': 20,
#          'act': 20,
#          'Department': 20,
#          'became': 20,
#          'race': 20,
#          'wanted': 20,
#          'action': 20,
#          '18': 20,
#          'Thursday': 20,
#          'kind': 20,
#          'April': 20,
#          'attack': 20,
#          'history': 20,
#          'College': 20,
#          'involved': 20,
#          'line': 20,
#          'war': 20,
#          'started': 20,
#          '15': 20,
#          'playing': 20,
#          'machinery': 20,
#          'Service': 20,
#          'Belgians': 20,
#          'Legislature': 19,
#          'feel': 19,
#          'prices': 19,
#          'council': 19,
#          'face': 19,
#          'afternoon': 19,
#          '1958': 19,
#          'order': 19,
#          'probably': 19,
#          'coming': 19,
#          'question': 19,
#          'R.': 19,
#          'return': 19,
#          'Frank': 19,
#          '30': 19,
#          'problems': 19,
#          'themselves': 19,
#          'What': 19,
#          'rather': 19,
#          'East': 19,
#          'hospital': 19,
#          'individual': 19,
#          'power': 19,
#          'Hotel': 19,
#          'private': 19,
#          'Premier': 19,
#          'played': 19,
#          'shares': 19,
#          'proposed': 18,
#          'services': 18,
#          'Association': 18,
#          'costs': 18,
#          'medical': 18,
#          'Henry': 18,
#          'Georgia': 18,
#          'Sen.': 18,
#          'whether': 18,
#          'passed': 18,
#          'P.': 18,
#          'certain': 18,
#          'means': 18,
#          'companies': 18,
#          'amount': 18,
#          "I'm": 18,
#          'All': 18,
#          'college': 18,
#          'least': 18,
#          'cases': 18,
#          'defense': 18,
#          'Some': 18,
#          'indicated': 18,
#          'care': 18,
#          'nine': 18,
#          'cut': 18,
#          'lines': 18,
#          '11': 18,
#          'rule': 18,
#          'cars': 18,
#          'once': 18,
#          'half': 18,
#          'headquarters': 18,
#          'complete': 18,
#          'Joseph': 18,
#          'officers': 18,
#          'times': 18,
#          'town': 18,
#          'hand': 18,
#          'necessary': 18,
#          'full': 18,
#          'bring': 18,
#          '7': 18,
#          'G.': 18,
#          'front': 18,
#          'reason': 18,
#          'Jack': 18,
#          'opening': 18,
#          'plane': 18,
#          'turn': 18,
#          'Her': 18,
#          'Kowalski': 18,
#          'primary': 17,
#          'evidence': 17,
#          'charge': 17,
#          'effect': 17,
#          'Mayor': 17,
#          'attorney': 17,
#          'candidate': 17,
#          'getting': 17,
#          'campaign': 17,
#          'similar': 17,
#          'Board': 17,
#          'saw': 17,
#          'led': 17,
#          'attend': 17,
#          'district': 17,
#          'Two': 17,
#          'fine': 17,
#          '22': 17,
#          'development': 17,
#          'Island': 17,
#          'served': 17,
#          'Martin': 17,
#          'room': 17,
#          'social': 17,
#          'already': 17,
#          'Both': 17,
#          'student': 17,
#          'hour': 17,
#          'demand': 17,
#          'Council': 17,
#          'forces': 17,
#          'South': 17,
#          'situation': 17,
#          '25': 17,
#          'David': 17,
#          'Federal': 17,
#          'traffic': 17,
#          'position': 17,
#          'life': 17,
#          'Jim': 17,
#          'Moscow': 17,
#          'manager': 17,
#          'Avenue': 17,
#          'Then': 17,
#          'tried': 17,
#          'drive': 17,
#          'boy': 17,
#          'a.m.': 17,
#          'Church': 17,
#          'straight': 17,
#          'hole': 17,
#          'look': 17,
#          'white': 17,
#          'Christian': 17,
#          'further': 16,
#          'find': 16,
#          'date': 16,
#          'property': 16,
#          '13': 16,
#          'official': 16,
#          'relations': 16,
#          'near': 16,
#          'church': 16,
#          'seven': 16,
#          'designed': 16,
#          '6': 16,
#          'sent': 16,
#          'bills': 16,
#          'taking': 16,
#          'kept': 16,
#          'High': 16,
#          'working': 16,
#          'organization': 16,
#          'side': 16,
#          'stand': 16,
#          'within': 16,
#          'want': 16,
#          'spirit': 16,
#          'job': 16,
#          'move': 16,
#          'form': 16,
#          'religious': 16,
#          'across': 16,
#          'average': 16,
#          'turned': 16,
#          'Mitchell': 16,
#          'women': 16,
#          'share': 16,
#          'failed': 16,
#          'feet': 16,
#          'Last': 16,
#          "don't": 16,
#          'association': 16,
#          'products': 16,
#          'Robinson': 16,
#          'lead': 16,
#          'cost': 15,
#          'effective': 15,
#          'receive': 15,
#          'Jan.': 15,
#          'pass': 15,
#          'operation': 15,
#          'agreed': 15,
#          'Republicans': 15,
#          'worth': 15,
#          'test': 15,
#          'battle': 15,
#          'research': 15,
#          'event': 15,
#          'Education': 15,
#          "didn't": 15,
#          'soon': 15,
#          'Austin': 15,
#          'dollars': 15,
#          'merely': 15,
#          'firms': 15,
#          'cannot': 15,
#          'declared': 15,
#          'Houston': 15,
#          'live': 15,
#          'heard': 15,
#          'District': 15,
#          'felt': 15,
#          'Other': 15,
#          'others': 15,
#          'building': 15,
#          'workers': 15,
#          'thing': 15,
#          'spring': 15,
#          'economic': 15,
#          'Eisenhower': 15,
#          'Among': 15,
#          'Providence': 15,
#          'basis': 15,
#          'Central': 15,
#          'name': 15,
#          'presented': 15,
#          'charter': 15,
#          '100': 15,
#          'Park': 15,
#          'central': 15,
#          'talk': 15,
#          'June': 15,
#          'Day': 15,
#          'stage': 15,
#          'example': 15,
#          'above': 15,
#          'reached': 15,
#          'continued': 15,
#          'Kansas': 15,
#          'Oct.': 15,
#          'thought': 15,
#          'short': 15,
#          'Francisco': 15,
#          'golf': 15,
#          'mother': 15,
#          'First': 15,
#          'faculty': 15,
#          'Fulton': 14,
#          'Atlanta': 14,
#          'often': 14,
#          'generally': 14,
#          'additional': 14,
#          'legislation': 14,
#          'Williams': 14,
#          'Aj': 14,
#          'construction': 14,
#          'word': 14,
#          'something': 14,
#          'shot': 14,
#          'scheduled': 14,
#          'fight': 14,
#          'hearing': 14,
#          '17': 14,
#          'estimated': 14,
#          'tell': 14,
#          'proposal': 14,
#          'Louis': 14,
#          'needs': 14,
#          'football': 14,
#          'serious': 14,
#          'limited': 14,
#          'July': 14,
#          'summer': 14,
#          'health': 14,
#          'base': 14,
#          'following': 14,
#          "can't": 14,
#          'housing': 14,
#          'floor': 14,
#          'particularly': 14,
#          'General': 14,
#          'nuclear': 14,
#          'Union': 14,
#          'civil': 14,
#          'call': 14,
#          'level': 14,
#          'Mary': 14,
#          'parties': 14,
#          'league': 14,
#          'value': 14,
#          'nearly': 14,
#          'land': 14,
#          'Wagner': 14,
#          'conspiracy': 14,
#          'agreement': 14,
#          'round': 14,
#          'Philadelphia': 14,
#          'AP': 14,
#          'father': 14,
#          'Los': 14,
#          'modern': 14,
#          '5': 14,
#          'hits': 14,
#          'Ohio': 14,
#          '14': 14,
#          'So': 14,
#          'Arnold': 14,
#          'nor': 14,
#          'guests': 14,
#          'struck': 14,
#          'Emory': 14,
#          'coal': 14,
#          'term': 13,
#          'grand': 13,
#          'welfare': 13,
#          'counties': 13,
#          'fees': 13,
#          'couple': 13,
#          'strong': 13,
#          'governor': 13,
#          'Sam': 13,
#          'study': 13,
#          'read': 13,
#          'Davis': 13,
#          'calls': 13,
#          'measure': 13,
#          'current': 13,
#          'Howard': 13,
#          'population': 13,
#          "year's": 13,
#          'your': 13,
#          'honor': 13,
#          'television': 13,
#          'returned': 13,
#          'admitted': 13,
#          '9': 13,
#          'security': 13,
#          'grants': 13,
#          'payroll': 13,
#          'daily': 13,
#          'Each': 13,
#          'interested': 13,
#          'Cuba': 13,
#          'Morton': 13,
#          'Boston': 13,
#          'groups': 13,
#          'America': 13,
#          'nation': 13,
#          'important': 13,
#          'sense': 13,
#          'having': 13,
#          'theater': 13,
#          'developed': 13,
#          'sold': 13,
#          'luncheon': 13,
#          'really': 13,
#          'explained': 13,
#          'running': 13,
#          'followed': 13,
#          'fall': 13,
#          'am': 13,
#          'Thompson': 13,
#          "It's": 13,
#          'Nations': 13,
#          'N.': 13,
#          'decision': 13,
#          'Hill': 13,
#          'headed': 13,
#          'revenues': 13,
#          'Warren': 13,
#          'churches': 13,
#          'International': 13,
#          'Rev.': 13,
#          'verdict': 13,
#          'winning': 13,
#          'news': 13,
#          'coach': 13,
#          'condition': 13,
#          'seem': 13,
#          'book': 13,
#          'Pittsburgh': 13,
#          'tournament': 13,
#          'husband': 13,
#          'food': 13,
#          'unions': 13,
#          'secrets': 13,
#          'art': 13,
#          'Stein': 13,
#          'price': 13,
#          'U.N.': 13,
#          'charged': 12,
#          'reports': 12,
#          'voters': 12,
#          'follow': 12,
#          'However': 12,
#          'weekend': 12,
#          'officials': 12,
#          'audience': 12,
#          'areas': 12,
#          'ready': 12,
#          'road': 12,
#          'fund': 12,
#          'department': 12,
#          'apparently': 12,
#          'While': 12,
#          'worked': 12,
#          'seek': 12,
#          'Many': 12,
#          'seemed': 12,
#          'books': 12,
#          'personal': 12,
#          'Lawrence': 12,
#          'El': 12,
#          'hear': 12,
#          'letters': 12,
#          'believe': 12,
#          'although': 12,
#          'passing': 12,
#          'chief': 12,
#          'lost': 12,
#          'spent': 12,
#          'teaching': 12,
#          'junior': 12,
#          'close': 12,
#          'addition': 12,
#          'knew': 12,
#          'address': 12,
#          "it's": 12,
#          'ruled': 12,
#          'Americans': 12,
#          'programs': 12,
#          'caused': 12,
#          'More': 12,
#          'pressure': 12,
#          'immediate': 12,
#          'concerned': 12,
#          'walk': 12,
#          'clear': 12,
#          'prevent': 12,
#          'hardly': 12,
#          'trade': 12,
#          'nations': 12,
#          'favor': 12,
#          'growth': 12,
#          'executive': 12,
#          'opinion': 12,
#          'us': 12,
#          'neither': 12,
#          'movement': 12,
#          'using': 12,
#          'considered': 12,
#          'try': 12,
#          'shown': 12,
#          'lives': 12,
#          'Their': 12,
#          'view': 12,
#          'reasons': 12,
#          'Air': 12,
#          'Of': 12,
#          ...})

# %%
# Make skip gram of one size window
skip_grams = []
# loop each word sequence
# we starts from 1 because 0 has no context
# we stop at second last for the same reason
for sent in corpus:
    for i in range(1, len(sent) - 1):
        target = sent[i]
        context = [sent[i - 1], sent[i + 1]]
        for w in context:
            skip_grams.append((target, w))

skip_grams
# Out:
# [('Fulton', 'The'),
#  ('Fulton', 'County'),
#  ('County', 'Fulton'),
#  ('County', 'Grand'),
#  ('Grand', 'County'),
#  ('Grand', 'Jury'),
#  ('Jury', 'Grand'),
#  ('Jury', 'said'),
#  ('said', 'Jury'),
#  ('said', 'Friday'),
#  ('Friday', 'said'),
#  ('Friday', 'an'),
#  ('an', 'Friday'),
#  ('an', 'investigation'),
#  ('investigation', 'an'),
#  ('investigation', 'of'),
#  ('of', 'investigation'),
#  ('of', "Atlanta's"),
#  ("Atlanta's", 'of'),
#  ("Atlanta's", 'recent'),
#  ('recent', "Atlanta's"),
#  ('recent', 'primary'),
#  ('primary', 'recent'),
#  ('primary', 'election'),
#  ('election', 'primary'),
#  ('election', 'produced'),
#  ('produced', 'election'),
#  ('produced', '``'),
#  ('``', 'produced'),
#  ('``', 'no'),
#  ('no', '``'),
#  ('no', 'evidence'),
#  ('evidence', 'no'),
#  ('evidence', "''"),
#  ("''", 'evidence'),
#  ("''", 'that'),
#  ('that', "''"),
#  ('that', 'any'),
#  ('any', 'that'),
#  ('any', 'irregularities'),
#  ('irregularities', 'any'),
#  ('irregularities', 'took'),
#  ('took', 'irregularities'),
#  ('took', 'place'),
#  ('place', 'took'),
#  ('place', '.'),
#  ('jury', 'The'),
#  ('jury', 'further'),
#  ('further', 'jury'),
#  ('further', 'said'),
#  ('said', 'further'),
#  ('said', 'in'),
#  ('in', 'said'),
#  ('in', 'term-end'),
#  ('term-end', 'in'),
#  ('term-end', 'presentments'),
#  ('presentments', 'term-end'),
#  ('presentments', 'that'),
#  ('that', 'presentments'),
#  ('that', 'the'),
#  ('the', 'that'),
#  ('the', 'City'),
#  ('City', 'the'),
#  ('City', 'Executive'),
#  ('Executive', 'City'),
#  ('Executive', 'Committee'),
#  ('Committee', 'Executive'),
#  ('Committee', ','),
#  (',', 'Committee'),
#  (',', 'which'),
#  ('which', ','),
#  ('which', 'had'),
#  ('had', 'which'),
#  ('had', 'over-all'),
#  ('over-all', 'had'),
#  ('over-all', 'charge'),
#  ('charge', 'over-all'),
#  ('charge', 'of'),
#  ('of', 'charge'),
#  ('of', 'the'),
#  ('the', 'of'),
#  ('the', 'election'),
#  ('election', 'the'),
#  ('election', ','),
#  (',', 'election'),
#  (',', '``'),
#  ('``', ','),
#  ('``', 'deserves'),
#  ('deserves', '``'),
#  ('deserves', 'the'),
#  ('the', 'deserves'),
#  ('the', 'praise'),
#  ('praise', 'the'),
#  ('praise', 'and'),
#  ('and', 'praise'),
#  ('and', 'thanks'),
#  ('thanks', 'and'),
#  ('thanks', 'of'),
#  ('of', 'thanks'),
#  ('of', 'the'),
#  ('the', 'of'),
#  ('the', 'City'),
#  ('City', 'the'),
#  ('City', 'of'),
#  ('of', 'City'),
#  ('of', 'Atlanta'),
#  ('Atlanta', 'of'),
#  ('Atlanta', "''"),
#  ("''", 'Atlanta'),
#  ("''", 'for'),
#  ('for', "''"),
#  ('for', 'the'),
#  ('the', 'for'),
#  ('the', 'manner'),
#  ('manner', 'the'),
#  ('manner', 'in'),
#  ('in', 'manner'),
#  ('in', 'which'),
#  ('which', 'in'),
#  ('which', 'the'),
#  ('the', 'which'),
#  ('the', 'election'),
#  ('election', 'the'),
#  ('election', 'was'),
#  ('was', 'election'),
#  ('was', 'conducted'),
#  ('conducted', 'was'),
#  ('conducted', '.'),
#  ('September-October', 'The'),
#  ('September-October', 'term'),
#  ('term', 'September-October'),
#  ('term', 'jury'),
#  ('jury', 'term'),
#  ('jury', 'had'),
#  ('had', 'jury'),
#  ('had', 'been'),
#  ('been', 'had'),
#  ('been', 'charged'),
#  ('charged', 'been'),
#  ('charged', 'by'),
#  ('by', 'charged'),
#  ('by', 'Fulton'),
#  ('Fulton', 'by'),
#  ('Fulton', 'Superior'),
#  ('Superior', 'Fulton'),
#  ('Superior', 'Court'),
#  ('Court', 'Superior'),
#  ('Court', 'Judge'),
#  ('Judge', 'Court'),
#  ('Judge', 'Durwood'),
#  ('Durwood', 'Judge'),
#  ('Durwood', 'Pye'),
#  ('Pye', 'Durwood'),
#  ('Pye', 'to'),
#  ('to', 'Pye'),
#  ('to', 'investigate'),
#  ('investigate', 'to'),
#  ('investigate', 'reports'),
#  ('reports', 'investigate'),
#  ('reports', 'of'),
#  ('of', 'reports'),
#  ('of', 'possible'),
#  ('possible', 'of'),
#  ('possible', '``'),
#  ('``', 'possible'),
#  ('``', 'irregularities'),
#  ('irregularities', '``'),
#  ('irregularities', "''"),
#  ("''", 'irregularities'),
#  ("''", 'in'),
#  ('in', "''"),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'hard-fought'),
#  ('hard-fought', 'the'),
#  ('hard-fought', 'primary'),
#  ('primary', 'hard-fought'),
#  ('primary', 'which'),
#  ('which', 'primary'),
#  ('which', 'was'),
#  ('was', 'which'),
#  ('was', 'won'),
#  ('won', 'was'),
#  ('won', 'by'),
#  ('by', 'won'),
#  ('by', 'Mayor-nominate'),
#  ('Mayor-nominate', 'by'),
#  ('Mayor-nominate', 'Ivan'),
#  ('Ivan', 'Mayor-nominate'),
#  ('Ivan', 'Allen'),
#  ('Allen', 'Ivan'),
#  ('Allen', 'Jr.'),
#  ('Jr.', 'Allen'),
#  ('Jr.', '.'),
#  ('Only', '``'),
#  ('Only', 'a'),
#  ('a', 'Only'),
#  ('a', 'relative'),
#  ('relative', 'a'),
#  ('relative', 'handful'),
#  ('handful', 'relative'),
#  ('handful', 'of'),
#  ('of', 'handful'),
#  ('of', 'such'),
#  ('such', 'of'),
#  ('such', 'reports'),
#  ('reports', 'such'),
#  ('reports', 'was'),
#  ('was', 'reports'),
#  ('was', 'received'),
#  ('received', 'was'),
#  ('received', "''"),
#  ("''", 'received'),
#  ("''", ','),
#  (',', "''"),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'jury'),
#  ('jury', 'the'),
#  ('jury', 'said'),
#  ('said', 'jury'),
#  ('said', ','),
#  (',', 'said'),
#  (',', '``'),
#  ('``', ','),
#  ('``', 'considering'),
#  ('considering', '``'),
#  ('considering', 'the'),
#  ('the', 'considering'),
#  ('the', 'widespread'),
#  ('widespread', 'the'),
#  ('widespread', 'interest'),
#  ('interest', 'widespread'),
#  ('interest', 'in'),
#  ('in', 'interest'),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'election'),
#  ('election', 'the'),
#  ('election', ','),
#  (',', 'election'),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'number'),
#  ('number', 'the'),
#  ('number', 'of'),
#  ('of', 'number'),
#  ('of', 'voters'),
#  ('voters', 'of'),
#  ('voters', 'and'),
#  ('and', 'voters'),
#  ('and', 'the'),
#  ('the', 'and'),
#  ('the', 'size'),
#  ('size', 'the'),
#  ('size', 'of'),
#  ('of', 'size'),
#  ('of', 'this'),
#  ('this', 'of'),
#  ('this', 'city'),
#  ('city', 'this'),
#  ('city', "''"),
#  ("''", 'city'),
#  ("''", '.'),
#  ('jury', 'The'),
#  ('jury', 'said'),
#  ('said', 'jury'),
#  ('said', 'it'),
#  ('it', 'said'),
#  ('it', 'did'),
#  ('did', 'it'),
#  ('did', 'find'),
#  ('find', 'did'),
#  ('find', 'that'),
#  ('that', 'find'),
#  ('that', 'many'),
#  ('many', 'that'),
#  ('many', 'of'),
#  ('of', 'many'),
#  ('of', "Georgia's"),
#  ("Georgia's", 'of'),
#  ("Georgia's", 'registration'),
#  ('registration', "Georgia's"),
#  ('registration', 'and'),
#  ('and', 'registration'),
#  ('and', 'election'),
#  ('election', 'and'),
#  ('election', 'laws'),
#  ('laws', 'election'),
#  ('laws', '``'),
#  ('``', 'laws'),
#  ('``', 'are'),
#  ('are', '``'),
#  ('are', 'outmoded'),
#  ('outmoded', 'are'),
#  ('outmoded', 'or'),
#  ('or', 'outmoded'),
#  ('or', 'inadequate'),
#  ('inadequate', 'or'),
#  ('inadequate', 'and'),
#  ('and', 'inadequate'),
#  ('and', 'often'),
#  ('often', 'and'),
#  ('often', 'ambiguous'),
#  ('ambiguous', 'often'),
#  ('ambiguous', "''"),
#  ("''", 'ambiguous'),
#  ("''", '.'),
#  ('recommended', 'It'),
#  ('recommended', 'that'),
#  ('that', 'recommended'),
#  ('that', 'Fulton'),
#  ('Fulton', 'that'),
#  ('Fulton', 'legislators'),
#  ('legislators', 'Fulton'),
#  ('legislators', 'act'),
#  ('act', 'legislators'),
#  ('act', '``'),
#  ('``', 'act'),
#  ('``', 'to'),
#  ('to', '``'),
#  ('to', 'have'),
#  ('have', 'to'),
#  ('have', 'these'),
#  ('these', 'have'),
#  ('these', 'laws'),
#  ('laws', 'these'),
#  ('laws', 'studied'),
#  ('studied', 'laws'),
#  ('studied', 'and'),
#  ('and', 'studied'),
#  ('and', 'revised'),
#  ('revised', 'and'),
#  ('revised', 'to'),
#  ('to', 'revised'),
#  ('to', 'the'),
#  ('the', 'to'),
#  ('the', 'end'),
#  ('end', 'the'),
#  ('end', 'of'),
#  ('of', 'end'),
#  ('of', 'modernizing'),
#  ('modernizing', 'of'),
#  ('modernizing', 'and'),
#  ('and', 'modernizing'),
#  ('and', 'improving'),
#  ('improving', 'and'),
#  ('improving', 'them'),
#  ('them', 'improving'),
#  ('them', "''"),
#  ("''", 'them'),
#  ("''", '.'),
#  ('grand', 'The'),
#  ('grand', 'jury'),
#  ('jury', 'grand'),
#  ('jury', 'commented'),
#  ('commented', 'jury'),
#  ('commented', 'on'),
#  ('on', 'commented'),
#  ('on', 'a'),
#  ('a', 'on'),
#  ('a', 'number'),
#  ('number', 'a'),
#  ('number', 'of'),
#  ('of', 'number'),
#  ('of', 'other'),
#  ('other', 'of'),
#  ('other', 'topics'),
#  ('topics', 'other'),
#  ('topics', ','),
#  (',', 'topics'),
#  (',', 'among'),
#  ('among', ','),
#  ('among', 'them'),
#  ('them', 'among'),
#  ('them', 'the'),
#  ('the', 'them'),
#  ('the', 'Atlanta'),
#  ('Atlanta', 'the'),
#  ('Atlanta', 'and'),
#  ('and', 'Atlanta'),
#  ('and', 'Fulton'),
#  ('Fulton', 'and'),
#  ('Fulton', 'County'),
#  ('County', 'Fulton'),
#  ('County', 'purchasing'),
#  ('purchasing', 'County'),
#  ('purchasing', 'departments'),
#  ('departments', 'purchasing'),
#  ('departments', 'which'),
#  ('which', 'departments'),
#  ('which', 'it'),
#  ('it', 'which'),
#  ('it', 'said'),
#  ('said', 'it'),
#  ('said', '``'),
#  ('``', 'said'),
#  ('``', 'are'),
#  ('are', '``'),
#  ('are', 'well'),
#  ('well', 'are'),
#  ('well', 'operated'),
#  ('operated', 'well'),
#  ('operated', 'and'),
#  ('and', 'operated'),
#  ('and', 'follow'),
#  ('follow', 'and'),
#  ('follow', 'generally'),
#  ('generally', 'follow'),
#  ('generally', 'accepted'),
#  ('accepted', 'generally'),
#  ('accepted', 'practices'),
#  ('practices', 'accepted'),
#  ('practices', 'which'),
#  ('which', 'practices'),
#  ('which', 'inure'),
#  ('inure', 'which'),
#  ('inure', 'to'),
#  ('to', 'inure'),
#  ('to', 'the'),
#  ('the', 'to'),
#  ('the', 'best'),
#  ('best', 'the'),
#  ('best', 'interest'),
#  ('interest', 'best'),
#  ('interest', 'of'),
#  ('of', 'interest'),
#  ('of', 'both'),
#  ('both', 'of'),
#  ('both', 'governments'),
#  ('governments', 'both'),
#  ('governments', "''"),
#  ("''", 'governments'),
#  ("''", '.'),
#  (',', 'However'),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'jury'),
#  ('jury', 'the'),
#  ('jury', 'said'),
#  ('said', 'jury'),
#  ('said', 'it'),
#  ('it', 'said'),
#  ('it', 'believes'),
#  ('believes', 'it'),
#  ('believes', '``'),
#  ('``', 'believes'),
#  ('``', 'these'),
#  ('these', '``'),
#  ('these', 'two'),
#  ('two', 'these'),
#  ('two', 'offices'),
#  ('offices', 'two'),
#  ('offices', 'should'),
#  ('should', 'offices'),
#  ('should', 'be'),
#  ('be', 'should'),
#  ('be', 'combined'),
#  ('combined', 'be'),
#  ('combined', 'to'),
#  ('to', 'combined'),
#  ('to', 'achieve'),
#  ('achieve', 'to'),
#  ('achieve', 'greater'),
#  ('greater', 'achieve'),
#  ('greater', 'efficiency'),
#  ('efficiency', 'greater'),
#  ('efficiency', 'and'),
#  ('and', 'efficiency'),
#  ('and', 'reduce'),
#  ('reduce', 'and'),
#  ('reduce', 'the'),
#  ('the', 'reduce'),
#  ('the', 'cost'),
#  ('cost', 'the'),
#  ('cost', 'of'),
#  ('of', 'cost'),
#  ('of', 'administration'),
#  ('administration', 'of'),
#  ('administration', "''"),
#  ("''", 'administration'),
#  ("''", '.'),
#  ('City', 'The'),
#  ('City', 'Purchasing'),
#  ('Purchasing', 'City'),
#  ('Purchasing', 'Department'),
#  ('Department', 'Purchasing'),
#  ('Department', ','),
#  (',', 'Department'),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'jury'),
#  ('jury', 'the'),
#  ('jury', 'said'),
#  ('said', 'jury'),
#  ('said', ','),
#  (',', 'said'),
#  (',', '``'),
#  ('``', ','),
#  ('``', 'is'),
#  ('is', '``'),
#  ('is', 'lacking'),
#  ('lacking', 'is'),
#  ('lacking', 'in'),
#  ('in', 'lacking'),
#  ('in', 'experienced'),
#  ('experienced', 'in'),
#  ('experienced', 'clerical'),
#  ('clerical', 'experienced'),
#  ('clerical', 'personnel'),
#  ('personnel', 'clerical'),
#  ('personnel', 'as'),
#  ('as', 'personnel'),
#  ('as', 'a'),
#  ('a', 'as'),
#  ('a', 'result'),
#  ('result', 'a'),
#  ('result', 'of'),
#  ('of', 'result'),
#  ('of', 'city'),
#  ('city', 'of'),
#  ('city', 'personnel'),
#  ('personnel', 'city'),
#  ('personnel', 'policies'),
#  ('policies', 'personnel'),
#  ('policies', "''"),
#  ("''", 'policies'),
#  ("''", '.'),
#  ('urged', 'It'),
#  ('urged', 'that'),
#  ('that', 'urged'),
#  ('that', 'the'),
#  ('the', 'that'),
#  ('the', 'city'),
#  ('city', 'the'),
#  ('city', '``'),
#  ('``', 'city'),
#  ('``', 'take'),
#  ('take', '``'),
#  ('take', 'steps'),
#  ('steps', 'take'),
#  ('steps', 'to'),
#  ('to', 'steps'),
#  ('to', 'remedy'),
#  ('remedy', 'to'),
#  ('remedy', "''"),
#  ("''", 'remedy'),
#  ("''", 'this'),
#  ('this', "''"),
#  ('this', 'problem'),
#  ('problem', 'this'),
#  ('problem', '.'),
#  ('of', 'Implementation'),
#  ('of', "Georgia's"),
#  ("Georgia's", 'of'),
#  ("Georgia's", 'automobile'),
#  ('automobile', "Georgia's"),
#  ('automobile', 'title'),
#  ('title', 'automobile'),
#  ('title', 'law'),
#  ('law', 'title'),
#  ('law', 'was'),
#  ('was', 'law'),
#  ('was', 'also'),
#  ('also', 'was'),
#  ('also', 'recommended'),
#  ('recommended', 'also'),
#  ('recommended', 'by'),
#  ('by', 'recommended'),
#  ('by', 'the'),
#  ('the', 'by'),
#  ('the', 'outgoing'),
#  ('outgoing', 'the'),
#  ('outgoing', 'jury'),
#  ('jury', 'outgoing'),
#  ('jury', '.'),
#  ('urged', 'It'),
#  ('urged', 'that'),
#  ('that', 'urged'),
#  ('that', 'the'),
#  ('the', 'that'),
#  ('the', 'next'),
#  ('next', 'the'),
#  ('next', 'Legislature'),
#  ('Legislature', 'next'),
#  ('Legislature', '``'),
#  ('``', 'Legislature'),
#  ('``', 'provide'),
#  ('provide', '``'),
#  ('provide', 'enabling'),
#  ('enabling', 'provide'),
#  ('enabling', 'funds'),
#  ('funds', 'enabling'),
#  ('funds', 'and'),
#  ('and', 'funds'),
#  ('and', 're-set'),
#  ('re-set', 'and'),
#  ('re-set', 'the'),
#  ('the', 're-set'),
#  ('the', 'effective'),
#  ('effective', 'the'),
#  ('effective', 'date'),
#  ('date', 'effective'),
#  ('date', 'so'),
#  ('so', 'date'),
#  ('so', 'that'),
#  ('that', 'so'),
#  ('that', 'an'),
#  ('an', 'that'),
#  ('an', 'orderly'),
#  ('orderly', 'an'),
#  ('orderly', 'implementation'),
#  ('implementation', 'orderly'),
#  ('implementation', 'of'),
#  ('of', 'implementation'),
#  ('of', 'the'),
#  ('the', 'of'),
#  ('the', 'law'),
#  ('law', 'the'),
#  ('law', 'may'),
#  ('may', 'law'),
#  ('may', 'be'),
#  ('be', 'may'),
#  ('be', 'effected'),
#  ('effected', 'be'),
#  ('effected', "''"),
#  ("''", 'effected'),
#  ("''", '.'),
#  ('grand', 'The'),
#  ('grand', 'jury'),
#  ('jury', 'grand'),
#  ('jury', 'took'),
#  ('took', 'jury'),
#  ('took', 'a'),
#  ('a', 'took'),
#  ('a', 'swipe'),
#  ('swipe', 'a'),
#  ('swipe', 'at'),
#  ('at', 'swipe'),
#  ('at', 'the'),
#  ('the', 'at'),
#  ('the', 'State'),
#  ('State', 'the'),
#  ('State', 'Welfare'),
#  ('Welfare', 'State'),
#  ('Welfare', "Department's"),
#  ("Department's", 'Welfare'),
#  ("Department's", 'handling'),
#  ('handling', "Department's"),
#  ('handling', 'of'),
#  ('of', 'handling'),
#  ('of', 'federal'),
#  ('federal', 'of'),
#  ('federal', 'funds'),
#  ('funds', 'federal'),
#  ('funds', 'granted'),
#  ('granted', 'funds'),
#  ('granted', 'for'),
#  ('for', 'granted'),
#  ('for', 'child'),
#  ('child', 'for'),
#  ('child', 'welfare'),
#  ('welfare', 'child'),
#  ('welfare', 'services'),
#  ('services', 'welfare'),
#  ('services', 'in'),
#  ('in', 'services'),
#  ('in', 'foster'),
#  ('foster', 'in'),
#  ('foster', 'homes'),
#  ('homes', 'foster'),
#  ('homes', '.'),
#  ('This', '``'),
#  ('This', 'is'),
#  ('is', 'This'),
#  ('is', 'one'),
#  ('one', 'is'),
#  ('one', 'of'),
#  ('of', 'one'),
#  ('of', 'the'),
#  ('the', 'of'),
#  ('the', 'major'),
#  ('major', 'the'),
#  ('major', 'items'),
#  ('items', 'major'),
#  ('items', 'in'),
#  ('in', 'items'),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'Fulton'),
#  ('Fulton', 'the'),
#  ('Fulton', 'County'),
#  ('County', 'Fulton'),
#  ('County', 'general'),
#  ('general', 'County'),
#  ('general', 'assistance'),
#  ('assistance', 'general'),
#  ('assistance', 'program'),
#  ('program', 'assistance'),
#  ('program', "''"),
#  ("''", 'program'),
#  ("''", ','),
#  (',', "''"),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'jury'),
#  ('jury', 'the'),
#  ('jury', 'said'),
#  ('said', 'jury'),
#  ('said', ','),
#  (',', 'said'),
#  (',', 'but'),
#  ('but', ','),
#  ('but', 'the'),
#  ('the', 'but'),
#  ('the', 'State'),
#  ('State', 'the'),
#  ('State', 'Welfare'),
#  ('Welfare', 'State'),
#  ('Welfare', 'Department'),
#  ('Department', 'Welfare'),
#  ('Department', '``'),
#  ('``', 'Department'),
#  ('``', 'has'),
#  ('has', '``'),
#  ('has', 'seen'),
#  ('seen', 'has'),
#  ('seen', 'fit'),
#  ('fit', 'seen'),
#  ('fit', 'to'),
#  ('to', 'fit'),
#  ('to', 'distribute'),
#  ('distribute', 'to'),
#  ('distribute', 'these'),
#  ('these', 'distribute'),
#  ('these', 'funds'),
#  ('funds', 'these'),
#  ('funds', 'through'),
#  ('through', 'funds'),
#  ('through', 'the'),
#  ('the', 'through'),
#  ('the', 'welfare'),
#  ('welfare', 'the'),
#  ('welfare', 'departments'),
#  ('departments', 'welfare'),
#  ('departments', 'of'),
#  ('of', 'departments'),
#  ('of', 'all'),
#  ('all', 'of'),
#  ('all', 'the'),
#  ('the', 'all'),
#  ('the', 'counties'),
#  ('counties', 'the'),
#  ('counties', 'in'),
#  ('in', 'counties'),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'state'),
#  ('state', 'the'),
#  ('state', 'with'),
#  ('with', 'state'),
#  ('with', 'the'),
#  ('the', 'with'),
#  ('the', 'exception'),
#  ('exception', 'the'),
#  ('exception', 'of'),
#  ('of', 'exception'),
#  ('of', 'Fulton'),
#  ('Fulton', 'of'),
#  ('Fulton', 'County'),
#  ('County', 'Fulton'),
#  ('County', ','),
#  (',', 'County'),
#  (',', 'which'),
#  ('which', ','),
#  ('which', 'receives'),
#  ('receives', 'which'),
#  ('receives', 'none'),
#  ('none', 'receives'),
#  ('none', 'of'),
#  ('of', 'none'),
#  ('of', 'this'),
#  ('this', 'of'),
#  ('this', 'money'),
#  ('money', 'this'),
#  ('money', '.'),
#  ('jurors', 'The'),
#  ('jurors', 'said'),
#  ('said', 'jurors'),
#  ('said', 'they'),
#  ('they', 'said'),
#  ('they', 'realize'),
#  ('realize', 'they'),
#  ('realize', '``'),
#  ('``', 'realize'),
#  ('``', 'a'),
#  ('a', '``'),
#  ('a', 'proportionate'),
#  ('proportionate', 'a'),
#  ('proportionate', 'distribution'),
#  ('distribution', 'proportionate'),
#  ('distribution', 'of'),
#  ('of', 'distribution'),
#  ('of', 'these'),
#  ('these', 'of'),
#  ('these', 'funds'),
#  ('funds', 'these'),
#  ('funds', 'might'),
#  ('might', 'funds'),
#  ('might', 'disable'),
#  ('disable', 'might'),
#  ('disable', 'this'),
#  ('this', 'disable'),
#  ('this', 'program'),
#  ('program', 'this'),
#  ('program', 'in'),
#  ('in', 'program'),
#  ('in', 'our'),
#  ('our', 'in'),
#  ('our', 'less'),
#  ('less', 'our'),
#  ('less', 'populous'),
#  ('populous', 'less'),
#  ('populous', 'counties'),
#  ('counties', 'populous'),
#  ('counties', "''"),
#  ("''", 'counties'),
#  ("''", '.'),
#  (',', 'Nevertheless'),
#  (',', '``'),
#  ('``', ','),
#  ('``', 'we'),
#  ('we', '``'),
#  ('we', 'feel'),
#  ('feel', 'we'),
#  ('feel', 'that'),
#  ('that', 'feel'),
#  ('that', 'in'),
#  ('in', 'that'),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'future'),
#  ('future', 'the'),
#  ('future', 'Fulton'),
#  ('Fulton', 'future'),
#  ('Fulton', 'County'),
#  ('County', 'Fulton'),
#  ('County', 'should'),
#  ('should', 'County'),
#  ('should', 'receive'),
#  ('receive', 'should'),
#  ('receive', 'some'),
#  ('some', 'receive'),
#  ('some', 'portion'),
#  ('portion', 'some'),
#  ('portion', 'of'),
#  ('of', 'portion'),
#  ('of', 'these'),
#  ('these', 'of'),
#  ('these', 'available'),
#  ('available', 'these'),
#  ('available', 'funds'),
#  ('funds', 'available'),
#  ('funds', "''"),
#  ("''", 'funds'),
#  ("''", ','),
#  (',', "''"),
#  (',', 'the'),
#  ('the', ','),
#  ('the', 'jurors'),
#  ('jurors', 'the'),
#  ('jurors', 'said'),
#  ('said', 'jurors'),
#  ('said', '.'),
#  ('Failure', '``'),
#  ('Failure', 'to'),
#  ('to', 'Failure'),
#  ('to', 'do'),
#  ('do', 'to'),
#  ('do', 'this'),
#  ('this', 'do'),
#  ('this', 'will'),
#  ('will', 'this'),
#  ('will', 'continue'),
#  ('continue', 'will'),
#  ('continue', 'to'),
#  ('to', 'continue'),
#  ('to', 'place'),
#  ('place', 'to'),
#  ('place', 'a'),
#  ('a', 'place'),
#  ('a', 'disproportionate'),
#  ('disproportionate', 'a'),
#  ('disproportionate', 'burden'),
#  ('burden', 'disproportionate'),
#  ('burden', "''"),
#  ("''", 'burden'),
#  ("''", 'on'),
#  ('on', "''"),
#  ('on', 'Fulton'),
#  ('Fulton', 'on'),
#  ('Fulton', 'taxpayers'),
#  ('taxpayers', 'Fulton'),
#  ('taxpayers', '.'),
#  ('jury', 'The'),
#  ('jury', 'also'),
#  ('also', 'jury'),
#  ('also', 'commented'),
#  ('commented', 'also'),
#  ('commented', 'on'),
#  ('on', 'commented'),
#  ('on', 'the'),
#  ('the', 'on'),
#  ('the', 'Fulton'),
#  ('Fulton', 'the'),
#  ('Fulton', "ordinary's"),
#  ("ordinary's", 'Fulton'),
#  ("ordinary's", 'court'),
#  ('court', "ordinary's"),
#  ('court', 'which'),
#  ('which', 'court'),
#  ('which', 'has'),
#  ('has', 'which'),
#  ('has', 'been'),
#  ('been', 'has'),
#  ('been', 'under'),
#  ('under', 'been'),
#  ('under', 'fire'),
#  ('fire', 'under'),
#  ('fire', 'for'),
#  ('for', 'fire'),
#  ('for', 'its'),
#  ('its', 'for'),
#  ('its', 'practices'),
#  ('practices', 'its'),
#  ('practices', 'in'),
#  ('in', 'practices'),
#  ('in', 'the'),
#  ('the', 'in'),
#  ('the', 'appointment'),
#  ('appointment', 'the'),
#  ('appointment', 'of'),
#  ('of', 'appointment'),
#  ('of', 'appraisers'),
#  ('appraisers', 'of'),
#  ('appraisers', ','),
#  (',', 'appraisers'),
#  (',', 'guardians'),
#  ('guardians', ','),
#  ('guardians', 'and'),
#  ('and', 'guardians'),
#  ('and', 'administrators'),
#  ('administrators', 'and'),
#  ('administrators', 'and'),
#  ('and', 'administrators'),
#  ('and', 'the'),
#  ('the', 'and'),
#  ('the', 'awarding'),
#  ('awarding', 'the'),
#  ('awarding', 'of'),
#  ('of', 'awarding'),
#  ('of', 'fees'),
#  ('fees', 'of'),
#  ('fees', 'and'),
#  ('and', 'fees'),
#  ('and', 'compensation'),
#  ('compensation', 'and'),
#  ('compensation', '.'),
#  ('jury', 'The'),
#  ('jury', 'said'),
#  ('said', 'jury'),
#  ('said', 'it'),
#  ('it', 'said'),
#  ('it', 'found'),
#  ('found', 'it'),
#  ('found', 'the'),
#  ('the', 'found'),
#  ('the', 'court'),
#  ('court', 'the'),
#  ('court', '``'),
#  ('``', 'court'),
#  ('``', 'has'),
#  ('has', '``'),
#  ('has', 'incorporated'),
#  ('incorporated', 'has'),
#  ('incorporated', 'into'),
#  ('into', 'incorporated'),
#  ('into', 'its'),
#  ('its', 'into'),
#  ('its', 'operating'),
#  ('operating', 'its'),
#  ('operating', 'procedures'),
#  ('procedures', 'operating'),
#  ('procedures', 'the'),
#  ('the', 'procedures'),
#  ('the', 'recommendations'),
#  ('recommendations', 'the'),
#  ('recommendations', "''"),
#  ("''", 'recommendations'),
#  ("''", 'of'),
#  ...]

# %%
X_ik_skipgram = Counter(skip_grams) # Co-occurece in window size 1
X_ik_skipgram
# Out:
# Counter({('of', 'the'): 844,
#          ('the', 'of'): 844,
#          ('in', 'the'): 549,
#          ('the', 'in'): 549,
#          (',', 'and'): 390,
#          ('and', ','): 390,
#          (',', 'the'): 364,
#          ('the', ','): 364,
#          ("''", '.'): 293,
#          ('to', 'the'): 273,
#          ('the', 'to'): 273,
#          ('on', 'the'): 239,
#          ('the', 'on'): 239,
#          ('for', 'the'): 217,
#          ('the', 'for'): 217,
#          ("''", ','): 198,
#          (',', "''"): 198,
#          ('at', 'the'): 179,
#          ('the', 'at'): 179,
#          ('will', 'be'): 157,
#          ('be', 'will'): 157,
#          (';', ';'): 157,
#          ('that', 'the'): 146,
#          ('the', 'that'): 146,
#          ('and', 'the'): 136,
#          ('the', 'and'): 136,
#          ('with', 'the'): 135,
#          ('the', 'with'): 135,
#          (',', 'who'): 126,
#          ('who', ','): 126,
#          ('said', ','): 123,
#          (',', 'said'): 123,
#          ('he', ','): 122,
#          (',', 'he'): 122,
#          (',', 'a'): 121,
#          ('a', ','): 121,
#          ('in', 'a'): 117,
#          ('a', 'in'): 117,
#          ('of', 'a'): 114,
#          ('a', 'of'): 114,
#          ('to', 'be'): 112,
#          ('be', 'to'): 112,
#          ('by', 'the'): 111,
#          ('the', 'by'): 111,
#          ('from', 'the'): 100,
#          ('the', 'from'): 100,
#          ('said', 'he'): 96,
#          ('he', 'said'): 96,
#          (',', '``'): 95,
#          ('``', ','): 95,
#          (',', 'but'): 95,
#          ('for', 'a'): 95,
#          ('a', 'for'): 95,
#          ('but', ','): 94,
#          ('has', 'been'): 87,
#          ('been', 'has'): 87,
#          (',', 'in'): 82,
#          ('in', ','): 82,
#          ('as', 'a'): 81,
#          ('a', 'as'): 81,
#          ('said', '.'): 77,
#          ('is', 'a'): 77,
#          ('a', 'is'): 77,
#          (',', 'which'): 76,
#          ('which', ','): 76,
#          (',', 'Mrs.'): 73,
#          ('Mrs.', ','): 73,
#          ('and', 'Mrs.'): 73,
#          ('Mrs.', 'and'): 73,
#          ('the', 'first'): 71,
#          ('first', 'the'): 71,
#          ('with', 'a'): 71,
#          ('to', 'a'): 71,
#          ('a', 'to'): 71,
#          ('a', 'with'): 70,
#          (',', 'it'): 69,
#          ('it', ','): 69,
#          ('would', 'be'): 68,
#          ('be', 'would'): 68,
#          (',', 'of'): 68,
#          ('of', ','): 68,
#          (',', 'was'): 66,
#          ('was', ','): 66,
#          (',', 'however'): 63,
#          ('is', 'the'): 63,
#          ('the', 'is'): 63,
#          ('however', ','): 62,
#          ('one', 'of'): 61,
#          ('of', 'one'): 61,
#          (',', 'as'): 60,
#          ('as', ','): 60,
#          ('and', 'a'): 59,
#          ('a', 'and'): 59,
#          ('as', 'the'): 57,
#          ('the', 'as'): 57,
#          (',', 'with'): 54,
#          ('with', ','): 54,
#          ('more', 'than'): 53,
#          ('than', 'more'): 53,
#          ('on', 'a'): 52,
#          ('York', 'New'): 52,
#          ('and', 'Mr.'): 52,
#          ('a', 'on'): 51,
#          (',', 'to'): 51,
#          (',', 'is'): 51,
#          ('is', ','): 51,
#          ('I', '``'): 51,
#          ('per', 'cent'): 50,
#          ('cent', 'per'): 50,
#          ('to', ','): 50,
#          ('have', 'been'): 50,
#          ('been', 'have'): 50,
#          ('New', 'York'): 48,
#          ('over', 'the'): 48,
#          ('the', 'over'): 48,
#          ('was', 'a'): 47,
#          ('a', 'was'): 47,
#          ('the', 'United'): 46,
#          ('United', 'the'): 46,
#          ('had', 'been'): 45,
#          ('been', 'had'): 45,
#          ('the', 'state'): 45,
#          ('state', 'the'): 45,
#          (',', 'for'): 45,
#          ('for', ','): 45,
#          ('?', '?'): 45,
#          ('to', 'have'): 44,
#          ('have', 'to'): 44,
#          ('that', 'he'): 44,
#          ('he', 'that'): 44,
#          ('was', 'the'): 44,
#          ('the', 'was'): 44,
#          ('at', 'a'): 44,
#          ('a', 'at'): 44,
#          ('the', '``'): 43,
#          ('``', 'the'): 43,
#          ('into', 'the'): 43,
#          ('the', 'into'): 43,
#          ('Jr.', ','): 42,
#          (',', 'Jr.'): 42,
#          ('was', 'it'): 42,
#          ('out', 'of'): 42,
#          ('of', 'out'): 42,
#          ('it', 'was'): 41,
#          (',', 'that'): 41,
#          ('that', ','): 41,
#          ('said', 'the'): 41,
#          ('the', 'said'): 41,
#          ('he', 'was'): 41,
#          ('was', 'he'): 41,
#          ('get', 'to'): 40,
#          ('to', 'get'): 40,
#          ('by', 'a'): 39,
#          ('a', 'by'): 39,
#          ('he', 'had'): 39,
#          ('had', 'he'): 39,
#          ('is', 'that'): 39,
#          ('that', 'is'): 39,
#          (',', 'will'): 38,
#          ('will', ','): 38,
#          ('United', 'States'): 37,
#          ('States', 'United'): 37,
#          ('the', 'In'): 36,
#          ('The', '``'): 36,
#          ('year', '.'): 35,
#          ('under', 'the'): 35,
#          ('the', 'under'): 35,
#          ('in', 'his'): 35,
#          ('his', 'in'): 35,
#          ('of', 'his'): 35,
#          ('his', 'of'): 35,
#          ('is', 'It'): 35,
#          ('members', 'of'): 34,
#          ('of', 'members'): 34,
#          ('when', 'the'): 33,
#          ('the', 'when'): 33,
#          (',', 'has'): 33,
#          ('has', ','): 33,
#          ('the', 'same'): 33,
#          ('same', 'the'): 33,
#          ('of', 'all'): 32,
#          ('all', 'of'): 32,
#          ('said', 'that'): 32,
#          ('that', 'said'): 32,
#          ('was', 'It'): 32,
#          ('last', 'year'): 32,
#          ('year', 'last'): 32,
#          ('his', 'and'): 31,
#          ('about', 'the'): 31,
#          ('the', 'about'): 31,
#          ('it', 'is'): 31,
#          ('is', 'it'): 31,
#          ('as', 'well'): 31,
#          ('well', 'as'): 31,
#          ('Mr.', 'and'): 31,
#          ('and', 'his'): 30,
#          (',', 'or'): 30,
#          ('or', ','): 30,
#          ('the', 'U.S.'): 30,
#          ('U.S.', 'the'): 30,
#          (':', '``'): 30,
#          ('``', ':'): 30,
#          ('should', 'be'): 29,
#          ('be', 'should'): 29,
#          ('``', 'a'): 29,
#          ('a', '``'): 29,
#          ('the', 'new'): 29,
#          ('new', 'the'): 29,
#          ('a', 'year'): 29,
#          ('House', 'White'): 29,
#          ('the', 'President'): 29,
#          ('President', 'the'): 29,
#          ('during', 'the'): 29,
#          ('the', 'during'): 29,
#          (',', 'Mr.'): 29,
#          ('Mr.', ','): 29,
#          ('the', 'other'): 29,
#          ('other', 'the'): 29,
#          ('last', 'week'): 29,
#          ('week', 'last'): 29,
#          ('the', 'only'): 29,
#          ('only', 'the'): 29,
#          ('the', 'Congo'): 29,
#          ('Congo', 'the'): 29,
#          ('year', 'a'): 28,
#          ('some', 'of'): 28,
#          ('of', 'some'): 28,
#          ('go', 'to'): 28,
#          ('to', 'go'): 28,
#          ('in', 'this'): 28,
#          ('this', 'in'): 28,
#          ('after', 'the'): 28,
#          ('the', 'after'): 28,
#          ('president', 'of'): 28,
#          ('of', 'president'): 28,
#          ('White', 'House'): 28,
#          ('the', 'American'): 28,
#          ('American', 'the'): 28,
#          ('there', 'is'): 28,
#          ('is', 'there'): 28,
#          ('number', 'of'): 27,
#          ('of', 'number'): 27,
#          ('is', 'This'): 27,
#          ('the', 'past'): 27,
#          ('past', 'the'): 27,
#          ('and', 'other'): 27,
#          ('other', 'and'): 27,
#          ('the', 'last'): 27,
#          ('last', 'the'): 27,
#          ('a', 'new'): 26,
#          ('new', 'a'): 26,
#          ('week', '.'): 26,
#          (',', 'when'): 26,
#          ('when', ','): 26,
#          ('of', 'their'): 26,
#          ('their', 'of'): 26,
#          ('up', 'to'): 26,
#          ('to', 'up'): 26,
#          ('of', 'an'): 26,
#          ('an', 'of'): 26,
#          (',', 'they'): 26,
#          ('they', ','): 26,
#          (',', 'there'): 25,
#          ('there', ','): 25,
#          ('and', '--'): 25,
#          ('that', 'a'): 25,
#          ('a', 'that'): 25,
#          ('is', 'not'): 25,
#          ('not', 'is'): 25,
#          (',', 'are'): 25,
#          ('are', ','): 25,
#          (',', 'at'): 25,
#          ('at', ','): 25,
#          ('which', 'the'): 24,
#          ('the', 'which'): 24,
#          ('``', 'and'): 24,
#          ('daughter', ','): 24,
#          (',', 'daughter'): 24,
#          ('to', 'make'): 24,
#          ('make', 'to'): 24,
#          ('--', 'and'): 24,
#          ('the', 'House'): 24,
#          ('was', 'not'): 24,
#          ('not', 'was'): 24,
#          ('that', 'it'): 24,
#          ('it', 'that'): 24,
#          ('be', 'a'): 24,
#          ('a', 'be'): 24,
#          (',', 'have'): 24,
#          ('have', ','): 24,
#          ('of', 'this'): 23,
#          ('this', 'of'): 23,
#          ('the', 'city'): 23,
#          ('city', 'the'): 23,
#          ('may', 'be'): 23,
#          ('be', 'may'): 23,
#          ('and', '``'): 23,
#          ('be', 'the'): 23,
#          ('the', 'be'): 23,
#          ('according', 'to'): 23,
#          ('to', 'according'): 23,
#          ('against', 'the'): 23,
#          ('the', 'against'): 23,
#          ('House', 'the'): 23,
#          ('said', 'He'): 23,
#          ('the', 'two'): 23,
#          ('two', 'the'): 23,
#          ('of', 'its'): 23,
#          ('its', 'of'): 23,
#          ('was', 'He'): 23,
#          ('home', 'runs'): 23,
#          ('runs', 'home'): 23,
#          (',', 'according'): 22,
#          ('according', ','): 22,
#          ('can', 'be'): 22,
#          ('be', 'can'): 22,
#          ('chairman', 'of'): 22,
#          ('of', 'chairman'): 22,
#          (',', 'by'): 22,
#          ('by', ','): 22,
#          (',', 'president'): 22,
#          ('president', ','): 22,
#          ('We', '``'): 22,
#          ('this', 'year'): 22,
#          ('year', 'this'): 22,
#          (',', 'on'): 22,
#          ('on', ','): 22,
#          (',', 'Mantle'): 22,
#          ('in', 'which'): 21,
#          ('which', 'in'): 21,
#          ('through', 'the'): 21,
#          ('the', 'through'): 21,
#          ('all', 'the'): 21,
#          ('the', 'all'): 21,
#          ('did', 'not'): 21,
#          ('not', 'did'): 21,
#          ('to', 'take'): 21,
#          ('take', 'to'): 21,
#          ('expected', 'to'): 21,
#          ('to', 'expected'): 21,
#          ('before', 'the'): 21,
#          ('the', 'before'): 21,
#          (',', 'where'): 21,
#          ('where', ','): 21,
#          ('the', 'most'): 21,
#          ('most', 'the'): 21,
#          ('able', 'to'): 21,
#          ('to', 'able'): 21,
#          ('not', 'be'): 21,
#          ('be', 'not'): 21,
#          ('in', 'their'): 21,
#          ('their', 'in'): 21,
#          ('up', 'the'): 21,
#          ('the', 'up'): 21,
#          (')', '.'): 21,
#          ('the', 'jury'): 20,
#          ('jury', 'the'): 20,
#          ('the', 'Senate'): 20,
#          ('Senate', 'the'): 20,
#          ('it', '.'): 20,
#          (',', 'would'): 20,
#          ('would', ','): 20,
#          (',', 'an'): 20,
#          ('an', ','): 20,
#          ('and', 'that'): 20,
#          ('that', 'and'): 20,
#          ('and', 'was'): 20,
#          ('was', 'and'): 20,
#          ("''", '?'): 20,
#          ('?', "''"): 20,
#          ('year', ','): 20,
#          (',', 'year'): 20,
#          ('is', 'to'): 20,
#          ('to', 'is'): 20,
#          ('and', 'to'): 20,
#          ('to', 'and'): 20,
#          ('member', 'of'): 20,
#          ('of', 'member'): 20,
#          ('S.', 'U.'): 20,
#          ('had', 'a'): 20,
#          ('a', 'had'): 20,
#          ('the', 'White'): 20,
#          ('White', 'the'): 20,
#          (')', ','): 20,
#          (',', ')'): 20,
#          (',', 'Maris'): 20,
#          ('a', 'result'): 19,
#          ('result', 'a'): 19,
#          ('have', 'a'): 19,
#          ('a', 'have'): 19,
#          ('there', 'was'): 19,
#          ('was', 'there'): 19,
#          ('when', 'he'): 19,
#          ('he', 'when'): 19,
#          (',', 'including'): 19,
#          ('including', ','): 19,
#          ('in', 'Dallas'): 19,
#          ('Dallas', 'in'): 19,
#          ('the', 'time'): 19,
#          ('time', 'the'): 19,
#          ('Kennedy', 'President'): 19,
#          ('of', 'that'): 19,
#          ('that', 'of'): 19,
#          ('part', 'of'): 19,
#          ('of', 'part'): 19,
#          ('for', 'his'): 19,
#          ('his', 'for'): 19,
#          ('off', 'the'): 19,
#          ('the', 'off'): 19,
#          ('the', 'board'): 19,
#          ('board', 'the'): 19,
#          ('to', 'try'): 19,
#          ('try', 'to'): 19,
#          ('``', 'The'): 19,
#          ('U.', 'S.'): 19,
#          ('!', '!'): 19,
#          ('the', 'ball'): 19,
#          ('ball', 'the'): 19,
#          ('Maris', ','): 19,
#          (',', 'says'): 19,
#          ('says', ','): 19,
#          ('``', 'to'): 18,
#          ('to', '``'): 18,
#          ('a', 'number'): 18,
#          ('number', 'a'): 18,
#          ('of', 'these'): 18,
#          ('these', 'of'): 18,
#          ('to', 'do'): 18,
#          ('do', 'to'): 18,
#          ('he', 'would'): 18,
#          ('would', 'he'): 18,
#          ('there', 'were'): 18,
#          ('were', 'there'): 18,
#          ('years', '.'): 18,
#          ('who', 'is'): 18,
#          ('is', 'who'): 18,
#          ('has', 'a'): 18,
#          ('a', 'has'): 18,
#          (',', 'too'): 18,
#          ('too', ','): 18,
#          ('that', 'they'): 18,
#          ('they', 'that'): 18,
#          ('of', 'them'): 18,
#          ('them', 'of'): 18,
#          ('a', 'special'): 18,
#          ('special', 'a'): 18,
#          ('kind', 'of'): 18,
#          ('of', 'kind'): 18,
#          ('are', 'they'): 18,
#          ('was', 'in'): 18,
#          ('in', 'was'): 18,
#          ('were', 'they'): 18,
#          ('President', 'The'): 18,
#          ('``', 'I'): 18,
#          ('with', 'his'): 18,
#          ('his', 'with'): 18,
#          ('from', 'a'): 18,
#          ('a', 'from'): 18,
#          (',', 'this'): 18,
#          ('this', ','): 18,
#          ('the', 'Soviet'): 18,
#          ('Soviet', 'the'): 18,
#          ('last', 'night'): 18,
#          ('night', 'last'): 18,
#          ('the', 'world'): 18,
#          ('world', 'the'): 18,
#          ('in', 'an'): 18,
#          ('an', 'in'): 18,
#          ('1961', ','): 18,
#          (',', '1961'): 18,
#          ('the', 'year'): 18,
#          ('year', 'the'): 18,
#          (',', 'were'): 18,
#          ('were', ','): 18,
#          ('result', 'of'): 17,
#          ('of', 'result'): 17,
#          ('the', 'State'): 17,
#          ('State', 'the'): 17,
#          ('the', 'but'): 17,
#          ('of', 'two'): 17,
#          ('two', 'of'): 17,
#          ('in', 'and'): 17,
#          ('wife', ','): 17,
#          (',', 'wife'): 17,
#          ('would', 'not'): 17,
#          ('not', 'would'): 17,
#          ('must', 'be'): 17,
#          ('be', 'must'): 17,
#          ('in', 'its'): 17,
#          ('its', 'in'): 17,
#          ('of', 'our'): 17,
#          ('our', 'of'): 17,
#          ('him', 'to'): 17,
#          ('to', 'him'): 17,
#          ('since', 'the'): 17,
#          ('the', 'since'): 17,
#          ('they', 'are'): 17,
#          ('between', 'the'): 17,
#          ('the', 'between'): 17,
#          ('they', 'were'): 17,
#          (',', 'if'): 17,
#          ('if', ','): 17,
#          ('than', 'the'): 17,
#          ('the', 'than'): 17,
#          ('the', '--'): 17,
#          (',', 'then'): 17,
#          ('then', ','): 17,
#          (',', 'after'): 17,
#          ('after', ','): 17,
#          ('the', 'National'): 17,
#          ('National', 'the'): 17,
#          ('and', 'he'): 17,
#          ('he', 'and'): 17,
#          ('the', 'next'): 16,
#          ('next', 'the'): 16,
#          ('but', 'the'): 16,
#          ('and', 'in'): 16,
#          ('would', 'have'): 16,
#          ('have', 'would'): 16,
#          ('cent', 'of'): 16,
#          ('of', 'cent'): 16,
#          ('the', 'Legislature'): 16,
#          ('Legislature', 'the'): 16,
#          ('to', 'see'): 16,
#          ('see', 'to'): 16,
#          ('that', 'there'): 16,
#          ('there', 'that'): 16,
#          ('it', 'would'): 16,
#          ('would', 'it'): 16,
#          ('the', 'day'): 16,
#          ('day', 'the'): 16,
#          ('years', 'in'): 16,
#          ('in', 'years'): 16,
#          ('be', 'in'): 16,
#          ('in', 'be'): 16,
#          ('because', 'of'): 16,
#          ('of', 'because'): 16,
#          ('President', 'Kennedy'): 16,
#          ('this', 'week'): 16,
#          (',', 'had'): 16,
#          ('had', ','): 16,
#          ('--', 'the'): 16,
#          ('think', 'I'): 16,
#          ('the', 'New'): 16,
#          ('New', 'the'): 16,
#          ('of', 'three'): 16,
#          ('three', 'of'): 16,
#          ('they', 'have'): 16,
#          ('have', 'they'): 16,
#          ('Mantle', ','): 16,
#          ('the', 'best'): 15,
#          ('best', 'the'): 15,
#          ('his', 'wife'): 15,
#          ('wife', 'his'): 15,
#          (',', 'one'): 15,
#          ('one', ','): 15,
#          ('--', 'a'): 15,
#          ('a', '--'): 15,
#          ('director', ','): 15,
#          (',', 'director'): 15,
#          ('time', '.'): 15,
#          ('who', 'has'): 15,
#          ('has', 'who'): 15,
#          ('is', 'expected'): 15,
#          ('expected', 'is'): 15,
#          ('as', 'they'): 15,
#          ('they', 'as'): 15,
#          (',', 'both'): 15,
#          ('both', ','): 15,
#          ('it', "''"): 15,
#          ("''", 'it'): 15,
#          ('to', 'pay'): 15,
#          ('pay', 'to'): 15,
#          ('at', 'least'): 15,
#          ('least', 'at'): 15,
#          ('board', 'of'): 15,
#          ('of', 'board'): 15,
#          ('University', 'of'): 15,
#          ('of', 'University'): 15,
#          ('as', 'an'): 15,
#          ('an', 'as'): 15,
#          ('``', 'of'): 15,
#          ('of', '``'): 15,
#          ('week', 'this'): 15,
#          ('who', 'had'): 15,
#          ('had', 'who'): 15,
#          (',', 'not'): 15,
#          ('not', ','): 15,
#          ('does', 'not'): 15,
#          ('not', 'does'): 15,
#          ('time', ','): 15,
#          (',', 'time'): 15,
#          ('a', 'few'): 15,
#          ('few', 'a'): 15,
#          ('years', 'ago'): 15,
#          ('ago', 'years'): 15,
#          ('going', 'to'): 15,
#          ('to', 'going'): 15,
#          ('the', 'people'): 15,
#          ('people', 'the'): 15,
#          ('a', 'member'): 15,
#          ('member', 'a'): 15,
#          (',', 'I'): 15,
#          ('I', ','): 15,
#          ('the', 'At'): 15,
#          ('is', 'no'): 15,
#          ('no', 'is'): 15,
#          ('Francisco', 'San'): 15,
#          ('the', 'Yankees'): 15,
#          ('Yankees', 'the'): 15,
#          ('in', 'home'): 15,
#          ('home', 'in'): 15,
#          ('the', 'U.'): 15,
#          ('U.', 'the'): 15,
#          ('the', 'administration'): 14,
#          ('administration', 'the'): 14,
#          ("''", 'and'): 14,
#          ('and', "''"): 14,
#          ('chairman', ','): 14,
#          (',', 'chairman'): 14,
#          ('is', 'in'): 14,
#          ('in', 'is'): 14,
#          (',', 'Texas'): 14,
#          ('most', 'of'): 14,
#          ('of', 'most'): 14,
#          ('series', 'of'): 14,
#          ('of', 'series'): 14,
#          ('is', 'being'): 14,
#          ('being', 'is'): 14,
#          (',', 'now'): 14,
#          ('now', ','): 14,
#          ('the', 'public'): 14,
#          ('public', 'the'): 14,
#          ('The', '--'): 14,
#          ('called', 'for'): 14,
#          ('for', 'called'): 14,
#          ('is', 'There'): 14,
#          ('than', 'rather'): 14,
#          ('them', '.'): 14,
#          ('as', 'much'): 14,
#          ('much', 'as'): 14,
#          ('of', 'those'): 14,
#          ('those', 'of'): 14,
#          ('them', 'to'): 14,
#          ('to', 'them'): 14,
#          (',', 'all'): 14,
#          ('all', ','): 14,
#          ('the', 'country'): 14,
#          ('country', 'the'): 14,
#          ('the', 'Republican'): 14,
#          ('Republican', 'the'): 14,
#          ('he', 'has'): 14,
#          ('has', 'he'): 14,
#          ('director', 'of'): 14,
#          ('of', 'director'): 14,
#          ('is', 'He'): 14,
#          ('the', 'way'): 14,
#          ('way', 'the'): 14,
#          ('man', 'the'): 14,
#          (',', 'whose'): 14,
#          ('whose', ','): 14,
#          ('(', 'AP'): 14,
#          ('AP', '('): 14,
#          ('AP', ')'): 14,
#          ('it', 'and'): 14,
#          (',', 'two'): 14,
#          ('two', ','): 14,
#          ('today', '.'): 14,
#          ('week', ','): 14,
#          (',', 'week'): 14,
#          ('the', 'university'): 14,
#          ('university', 'the'): 14,
#          ('Kennedy', 'Mr.'): 14,
#          ('the', 'anti-trust'): 14,
#          ('anti-trust', 'the'): 14,
#          ('anti-trust', 'laws'): 14,
#          ('laws', 'anti-trust'): 14,
#          ('said', 'it'): 13,
#          ('it', 'said'): 13,
#          ('many', 'of'): 13,
#          ('of', 'many'): 13,
#          ('the', 'end'): 13,
#          ('end', 'the'): 13,
#          ('was', 'also'): 13,
#          ('also', 'was'): 13,
#          ('This', '``'): 13,
#          ('is', 'one'): 13,
#          ('one', 'is'): 13,
#          ('son', ','): 13,
#          (',', 'son'): 13,
#          ('has', 'not'): 13,
#          ('not', 'has'): 13,
#          ('than', 'a'): 13,
#          ('a', 'than'): 13,
#          ('Aj', '.'): 13,
#          ('to', 'his'): 13,
#          ('his', 'to'): 13,
#          ('announced', 'that'): 13,
#          ('that', 'announced'): 13,
#          ('a', 'meeting'): 13,
#          ('meeting', 'a'): 13,
#          ('their', 'own'): 13,
#          ('own', 'their'): 13,
#          ('the', 'University'): 13,
#          ('University', 'the'): 13,
#          (',', 'Washington'): 13,
#          ('rather', 'than'): 13,
#          ('of', 'Secretary'): 13,
#          ('to', 'come'): 13,
#          ('come', 'to'): 13,
#          ('such', 'a'): 13,
#          ('a', 'such'): 13,
#          ('had', 'they'): 13,
#          ('had', 'to'): 13,
#          ('to', 'had'): 13,
#          ('the', 'problem'): 13,
#          ('problem', 'the'): 13,
#          ('the', 'home'): 13,
#          ('home', 'the'): 13,
#          ('I', 'think'): 13,
#          ('could', 'be'): 13,
#          ('be', 'could'): 13,
#          ('the', 'man'): 13,
#          ('of', 'New'): 13,
#          ('New', 'of'): 13,
#          ('decided', 'to'): 13,
#          ('to', 'decided'): 13,
#          ('and', 'is'): 13,
#          ('is', 'and'): 13,
#          ('the', 'meeting'): 13,
#          ('meeting', 'the'): 13,
#          ('the', 'project'): 13,
#          ('project', 'the'): 13,
#          ('Khrushchev', 'Premier'): 13,
#          ('for', 'their'): 13,
#          ('their', 'for'): 13,
#          ('the', 'big'): 13,
#          ('big', 'the'): 13,
#          ('the', 'third'): 13,
#          ('third', 'the'): 13,
#          ('after', 'a'): 13,
#          ('a', 'after'): 13,
#          ('City', 'Kansas'): 13,
#          ('failed', 'to'): 13,
#          ('to', 'failed'): 13,
#          (',', 'Fla.'): 13,
#          (',', 'up'): 13,
#          ('up', ','): 13,
#          ('had', 'the'): 13,
#          ('the', 'had'): 13,
#          ('San', 'Francisco'): 13,
#          ('went', 'to'): 13,
#          ('to', 'went'): 13,
#          ('and', 'her'): 13,
#          ('her', 'and'): 13,
#          (',', 'Calif.'): 13,
#          ('Calif.', ','): 13,
#          ('the', 'Belgians'): 13,
#          ('Belgians', 'the'): 13,
#          ('of', 'both'): 12,
#          ('both', 'of'): 12,
#          (',', 'However'): 12,
#          ('``', 'is'): 12,
#          ('is', '``'): 12,
#          ("''", 'on'): 12,
#          ('on', "''"): 12,
#          ('``', 'that'): 12,
#          ('that', '``'): 12,
#          ('2', ','): 12,
#          (',', '2'): 12,
#          ('back', 'to'): 12,
#          ('to', 'back'): 12,
#          ('up', 'for'): 12,
#          ('for', 'up'): 12,
#          ('be', 'held'): 12,
#          ('held', 'be'): 12,
#          ('in', 'Washington'): 12,
#          ('Washington', 'in'): 12,
#          ('he', 'But'): 12,
#          ('told', 'the'): 12,
#          ('the', 'told'): 12,
#          ('to', 'attend'): 12,
#          ('attend', 'to'): 12,
#          ('on', 'his'): 12,
#          ('his', 'on'): 12,
#          (',', 'from'): 12,
#          ('from', ','): 12,
#          ('need', 'for'): 12,
#          ('for', 'need'): 12,
#          ('project', '.'): 12,
#          ('high', 'school'): 12,
#          ('school', 'high'): 12,
#          ('who', 'are'): 12,
#          ('are', 'who'): 12,
#          ('the', 'Kennedy'): 12,
#          ('Kennedy', 'the'): 12,
#          ('who', 'have'): 12,
#          ('have', 'who'): 12,
#          ('years', ','): 12,
#          (',', 'years'): 12,
#          ('session', 'of'): 12,
#          ('of', 'session'): 12,
#          ('the', 'case'): 12,
#          ('case', 'the'): 12,
#          ('the', 'On'): 12,
#          ('Secretary', 'of'): 12,
#          ('fact', 'that'): 12,
#          ('that', 'fact'): 12,
#          ('they', 'had'): 12,
#          ('1959', ','): 12,
#          (',', '1959'): 12,
#          ('the', 'local'): 12,
#          ('local', 'the'): 12,
#          ('might', 'be'): 12,
#          ('be', 'might'): 12,
#          ('It', '``'): 12,
#          ('am', 'I'): 12,
#          ('to', 'bring'): 12,
#          ('bring', 'to'): 12,
#          ('a', 'little'): 12,
#          ('little', 'a'): 12,
#          ('are', 'There'): 12,
#          (',', 'she'): 12,
#          ('she', ','): 12,
#          ('and', 'they'): 12,
#          ('they', 'and'): 12,
#          (',', 'so'): 12,
#          ('so', ','): 12,
#          ('Kansas', 'City'): 12,
#          ('night', '.'): 12,
#          ('ago', ','): 12,
#          (',', 'ago'): 12,
#          ('Los', 'Angeles'): 12,
#          ('Angeles', 'Los'): 12,
#          ('and', 'it'): 12,
#          ('game', '.'): 12,
#          ('Fla.', ','): 12,
#          (',', 'March'): 12,
#          ('March', ','): 12,
#          ('the', 'game'): 12,
#          ('game', 'the'): 12,
#          ('to', 'play'): 12,
#          ('play', 'to'): 12,
#          ('in', 'front'): 12,
#          ('front', 'in'): 12,
#          ('plane', 'the'): 12,
#          ('as', 'it'): 12,
#          ('it', 'as'): 12,
#          (',', 'his'): 12,
#          ('his', ','): 12,
#          ('1960', ','): 12,
#          (',', '1960'): 12,
#          (',', 'Miss'): 12,
#          ('Miss', ','): 12,
#          ('a', 'car'): 12,
#          ('car', 'a'): 12,
#          ('to', 'work'): 11,
#          ('work', 'to'): 11,
#          ('bonds', '.'): 11,
#          ('work', 'on'): 11,
#          ('on', 'work'): 11,
#          ('was', 'no'): 11,
#          ('no', 'was'): 11,
#          ('like', 'to'): 11,
#          ('to', 'like'): 11,
#          ('to', 'provide'): 11,
#          ('provide', 'to'): 11,
#          ('schools', ','): 11,
#          (',', 'schools'): 11,
#          ('here', '.'): 11,
#          ('to', 'give'): 11,
#          ('give', 'to'): 11,
#          ('the', 'right'): 11,
#          ('right', 'the'): 11,
#          ('3', ','): 11,
#          (',', '3'): 11,
#          ('it', 'for'): 11,
#          ('for', 'it'): 11,
#          ('are', 'not'): 11,
#          ('not', 'are'): 11,
#          ('as', 'soon'): 11,
#          ('soon', 'as'): 11,
#          ('while', 'the'): 11,
#          ('the', 'while'): 11,
#          ('among', 'the'): 11,
#          ('the', 'among'): 11,
#          ('to', 'meet'): 11,
#          ('if', 'the'): 11,
#          ('the', 'if'): 11,
#          ('1', ','): 11,
#          (',', '1'): 11,
#          (',', 'because'): 11,
#          ('because', ','): 11,
#          ('at', 'home'): 11,
#          ('home', 'at'): 11,
#          ('his', 'own'): 11,
#          ('own', 'his'): 11,
#          ('the', "President's"): 11,
#          ("President's", 'the'): 11,
#          ('been', 'a'): 11,
#          ('a', 'been'): 11,
#          ('the', 'fact'): 11,
#          ('fact', 'the'): 11,
#          ('came', 'to'): 11,
#          ('to', 'came'): 11,
#          ('around', 'the'): 11,
#          ('the', 'around'): 11,
#          ('in', 'Laos'): 11,
#          ('Laos', 'in'): 11,
#          ('Laos', '.'): 11,
#          ('was', 'that'): 11,
#          ('that', 'was'): 11,
#          ('to', 'want'): 11,
#          ('want', 'to'): 11,
#          ('of', 'One'): 11,
#          ('a', 'complete'): 11,
#          ('complete', 'a'): 11,
#          ('with', 'an'): 11,
#          ('an', 'with'): 11,
#          ('back', 'in'): 11,
#          ('in', 'back'): 11,
#          ('are', 'the'): 11,
#          ('the', 'are'): 11,
#          ('day', '.'): 11,
#          ('was', 'I'): 11,
#          (',', 'Monday'): 11,
#          ('he', 'is'): 11,
#          ('is', 'he'): 11,
#          ('May', ','): 11,
#          (',', 'May'): 11,
#          ('the', 'early'): 11,
#          ('early', 'the'): 11,
#          ('the', 'national'): 11,
#          ('national', 'the'): 11,
#          ('which', 'is'): 11,
#          ('is', 'which'): 11,
#          ('to', 'an'): 11,
#          ('an', 'to'): 11,
#          ('Premier', 'Khrushchev'): 11,
#          ('Nations', 'United'): 11,
#          ('New', 'Orleans'): 11,
#          ('Orleans', 'New'): 11,
#          ('course', ','): 11,
#          (',', 'course'): 11,
#          ('as', 'long'): 11,
#          ('long', 'as'): 11,
#          (',', 'Inc.'): 11,
#          ('Inc.', ','): 11,
#          ('the', 'final'): 11,
#          ('final', 'the'): 11,
#          ('was', 'to'): 11,
#          ('to', 'was'): 11,
#          ('do', 'not'): 11,
#          ('not', 'do'): 11,
#          ('a', 'single'): 11,
#          ('single', 'a'): 11,
#          ('the', 'plane'): 11,
#          ('to', 'talk'): 11,
#          ('talk', 'to'): 11,
#          ('as', 'many'): 11,
#          ('many', 'as'): 11,
#          ('of', 'her'): 11,
#          ('her', 'of'): 11,
#          ('and', 'their'): 11,
#          ('their', 'and'): 11,
#          ('any', 'of'): 11,
#          ('of', 'any'): 11,
#          ('the', 'election'): 10,
#          ('election', 'the'): 10,
#          ('so', 'that'): 10,
#          ('that', 'so'): 10,
#          ('the', 'future'): 10,
#          ('future', 'the'): 10,
#          ("''", 'of'): 10,
#          ('of', "''"): 10,
#          ('it', 'to'): 10,
#          ('to', 'it'): 10,
#          ('and', 'then'): 10,
#          ('then', 'and'): 10,
#          ('were', 'not'): 10,
#          ('not', 'were'): 10,
#          ('to', 'set'): 10,
#          ('set', 'to'): 10,
#          ('education', ','): 10,
#          (',', 'education'): 10,
#          ('``', 'in'): 10,
#          ('in', '``'): 10,
#          ('a', 'long'): 10,
#          ('long', 'a'): 10,
#          ('18', ','): 10,
#          (',', '18'): 10,
#          ('after', 'he'): 10,
#          ('he', 'after'): 10,
#          ('which', 'he'): 10,
#          ('he', 'which'): 10,
#          ('the', 'committee'): 10,
#          ('committee', 'the'): 10,
#          ('bill', ','): 10,
#          (',', 'bill'): 10,
#          ('the', 'bill'): 10,
#          ...})

# %% [markdown]
# ### Weighting function
#
# GloVe includes a weighting function to scale down too frequent words.
#
# <img src = "figures/glove_weighting_func.png" width=400>

# %%
#simply a normalized function...don't worry too much
def weighting(w_i, w_j, X_ik):
        
    #check whether the co-occurrences exist between these two words
    try:
        x_ij = X_ik[(w_i, w_j)]
    except:
        x_ij = 1  #if does not exist, set it to 1
                
    x_max = 100 #100 # fixed in paper  #cannot exceed 100 counts
    alpha = 0.75
    
    #if co-occurrence does not exceed 100, scale it based on some alpha
    if x_ij < x_max:
        result = (x_ij/x_max)**alpha  #scale it
    else:
        result = 1  #if is greater than max, set it to 1 maximum
    
    return result

# %%
# from itertools import combinations_with_replacement

# X_ik = {}  #for keeping the co-occurences
# weighting_dic = {} #scaling the percentage of sampling

# for bigram in combinations_with_replacement(vocab, 2):
#     if X_ik_skipgram.get(bigram) is not None:  #matches 
#         co_occer = X_ik_skipgram[bigram]  #get the count from what we already counted
#         X_ik[bigram] = co_occer + 1 # + 1 for stability issue
#         X_ik[(bigram[1],bigram[0])] = co_occer + 1   #count also for the opposite
#     else:
#         pass
        
#     weighting_dic[bigram] = weighting(bigram[0], bigram[1], X_ik)
#     weighting_dic[(bigram[1], bigram[0])] = weighting(bigram[1], bigram[0], X_ik)

# print(f"{X_ik=}")
# print(f"{weighting_dic=}")

# %%
from itertools import combinations_with_replacement
from collections import defaultdict

X_ik = defaultdict(int)  # For keeping the co-occurrences
weighting_dic = defaultdict(float)  # Scaling the percentage of sampling


def weighting(word1, word2, X_ik):
    total_count = sum(X_ik.values())  # Get the total count of co-occurrences
    return X_ik.get((word1, word2), 0) / total_count if total_count > 0 else 0

for bigram in combinations_with_replacement(vocab, 2):
    if X_ik_skipgram.get(bigram) is not None:  # Matches
        co_occur = X_ik_skipgram[bigram]  # Get the count from what we already counted
        X_ik[bigram] += co_occur + 1  # +1 for stability issue
        X_ik[(bigram[1], bigram[0])] += co_occur + 1  # Count also for the opposite

    weighting_dic[bigram] = weighting(bigram[0], bigram[1], X_ik)
    weighting_dic[(bigram[1], bigram[0])] = weighting(bigram[1], bigram[0], X_ik)

# Print results
print(f"X_ik={dict(X_ik)}")  
print(f"weighting_dic={dict(weighting_dic)}")

# %% [markdown]
# ## 3. Prepare train data

# %%
for c in corpus:
    print(c)

# %%
import math

def random_batch(batch_size, word_sequence, skip_grams, X_ik, weighting_dic):
    
    #convert to id since our skip_grams is word, not yet id
    skip_grams_id = [(word2index[skip_gram[0]], word2index[skip_gram[1]]) for skip_gram in skip_grams]
    
    random_inputs = []
    random_labels = []
    random_coocs  = []
    random_weightings = []
    random_index = np.random.choice(range(len(skip_grams_id)), batch_size, replace=False) #randomly pick without replacement
        
    for i in random_index:
        random_inputs.append([skip_grams_id[i][0]])  # target, e.g., 2
        random_labels.append([skip_grams_id[i][1]])  # context word, e.g., 3
        
        #get cooc
        pair = skip_grams[i]
        try:
            cooc = X_ik[pair]
        except:
            cooc = 1
        random_coocs.append([math.log(cooc)])
        
        #get weighting
        weighting = weighting_dic[pair]
        random_weightings.append([weighting])
                    
    return np.array(random_inputs), np.array(random_labels), np.array(random_coocs), np.array(random_weightings)

# %% [markdown]
# ### Testing the method

# %%
#testing the method
batch_size = 2 # mini-batch size
input_batch, target_batch, cooc_batch, weighting_batch = random_batch(batch_size, corpus, skip_grams, X_ik, weighting_dic)

print("Input: ", input_batch)
print("Target: ", target_batch)
print("Cooc: ", cooc_batch)
print("Weighting: ", weighting_batch)

#we will convert them to tensor during training, so don't worry...

# %%
input_batch.shape, target_batch.shape

# %% [markdown]
# ## 4. Model
#
# <img src ="figures/glove.png">

# %%
class GloVe(nn.Module):
    
    def __init__(self, vocab_size,embed_size):
        super(GloVe,self).__init__()
        self.embedding_v = nn.Embedding(vocab_size, embed_size) # center embedding
        self.embedding_u = nn.Embedding(vocab_size, embed_size) # out embedding
        
        self.v_bias = nn.Embedding(vocab_size, 1)
        self.u_bias = nn.Embedding(vocab_size, 1)
        
    def forward(self, center_words, target_words, coocs, weighting):
        center_embeds = self.embedding_v(center_words) # [batch_size, 1, emb_size]
        target_embeds = self.embedding_u(target_words) # [batch_size, 1, emb_size]
        
        center_bias = self.v_bias(center_words).squeeze(1)
        target_bias = self.u_bias(target_words).squeeze(1)
        
        inner_product = target_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)
        #[batch_size, 1, emb_size] @ [batch_size, emb_size, 1] = [batch_size, 1, 1] = [batch_size, 1]
        
        #note that coocs already got log
        loss = weighting*torch.pow(inner_product +center_bias + target_bias - coocs, 2)
        
        return torch.sum(loss)

# %% [markdown]
# ## 5. Training

# %%
batch_size     = 10 # mini-batch size
embedding_size = 2 #so we can later plot
model          = GloVe(voc_size, embedding_size)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
import time

# Training
num_epochs = 50
for epoch in range(num_epochs):
    
    start = time.time()
    
    input_batch, target_batch, cooc_batch, weighting_batch = random_batch(batch_size, corpus, skip_grams, X_ik, weighting_dic)
    input_batch  = torch.LongTensor(input_batch)         #[batch_size, 1]
    target_batch = torch.LongTensor(target_batch)        #[batch_size, 1]
    cooc_batch   = torch.FloatTensor(cooc_batch)         #[batch_size, 1]
    weighting_batch = torch.FloatTensor(weighting_batch) #[batch_size, 1]
    
    optimizer.zero_grad()
    loss = model(input_batch, target_batch, cooc_batch, weighting_batch)
    
    loss.backward()
    optimizer.step()
    
    end = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start, end)

    if (epoch + 1) % 10 == 0:
        print(f"Epoch: {epoch + 1} | cost: {loss:.6f} | time: {epoch_mins}m {epoch_secs}s")

# %% [markdown]
# ## 6. Plotting the embeddings

# %%
#let's write a function to get embedding given a word
def get_embed(word):
    id_tensor = torch.LongTensor([word2index[word]])
    v_embed = model.embedding_v(id_tensor)
    u_embed = model.embedding_u(id_tensor) 
    word_embed = (v_embed + u_embed) / 2 
    x, y = word_embed[0][0].item(), word_embed[0][1].item()

    return x, y

# %%
plt.figure(figsize=(6,10))
for i, word in enumerate(vocab[:]): #loop each unique vocab
    x, y = get_embed(word)
    plt.scatter(x, y)
    plt.annotate(word, xy=(x, y), xytext=(5, 2), textcoords='offset points')
plt.show()

# %% [markdown]
# ## 7. Cosine similarity
#
# Formally the [Cosine Similarity](https://en.wikipedia.org/wiki/Cosine_similarity) $s$ between two vectors $p$ and $q$ is defined as:
#
# $$s = \frac{p \cdot q}{||p|| ||q||}, \textrm{ where } s \in [-1, 1] $$
#
# If $p$ and $q$ is super similar, the result is 1 otherwise 0.

# %%
with open('word-test_semantic.txt', 'r') as file:
    # Read the entire file content
    # dataset = file.read() 
    # print(dataset)

    # Read the file line by line
    # for line in file:
    #     print(line.strip()) 

    # Read all lines into a list
    data_sem = file.readlines()
    print(data_sem)

with open('word-test_syntactic.txt', 'r') as file:
    # Read all lines into a list
    data_syn = file.readlines()
    print(data_syn)

# %%
def clean_data(data):
    cleaned_data = []
    for line in data:
        cleaned_line = line.strip()  # Remove leading/trailing whitespace, including \n and \t
        cleaned_data.append(cleaned_line)

    return cleaned_data

# usage:
data_sem = clean_data(data_sem)
print(data_sem)

data_syn = clean_data(data_syn)
print(data_syn)

# %%
def parse_analogies(file_data):
    """
    Parse analogy datasets.
    Each analogy should be in the format: word1 word2 word3 word4
    """
    analogies = []
    for line in file_data:
        words = line.split()
        if len(words) == 4:
            analogies.append(tuple(words))
    return analogies

# Parse the datasets
semantic_analogies = parse_analogies(data_sem)
syntactic_analogies = parse_analogies(data_syn)

# %%
semantic_analogies

# %%
syntactic_analogies

# %%
def predict_word(model, word2index, index2word, analogy):
    word1, word2, word3, _ = analogy
    if word1 not in word2index or word2 not in word2index or word3 not in word2index:
        return '<UNK>'  # Return UNK if any word is out of vocabulary

    word1_idx = torch.LongTensor([word2index[word1]])
    word2_idx = torch.LongTensor([word2index[word2]])
    word3_idx = torch.LongTensor([word2index[word3]])

    # Get embeddings
    word1_embed = model.embedding_v(word1_idx)
    word2_embed = model.embedding_v(word2_idx)
    word3_embed = model.embedding_v(word3_idx)

    # Vector math: word2 - word1 + word3
    target_vector = word2_embed - word1_embed + word3_embed

    # Compute cosine similarity with all vocabulary embeddings
    all_embeddings = model.embedding_v.weight.data
    similarities = torch.nn.functional.cosine_similarity(target_vector, all_embeddings, dim=1)

    # Find the index of the most similar word
    predicted_idx = torch.argmax(similarities).item()
    return index2word[predicted_idx]

# %% [markdown]
# ## 8. Accuracy calculation: semantic and syntactic_accuracy

# %%
def calculate_accuracy(analogies, model, word2index, index2word):
    """
    Calculate accuracy for a given set of analogies.
    """
    correct = 0
    total = 0

    for analogy in analogies:
        total += 1
        predicted_word = predict_word(model, word2index, index2word, analogy)
        if predicted_word.lower() == analogy[3].lower():
            correct += 1

    return correct / total if total > 0 else 0

# %%
# Calculate syntactic and semantic accuracies
semantic_accuracy = calculate_accuracy(semantic_analogies, model, word2index, index2word)
syntactic_accuracy = calculate_accuracy(syntactic_analogies, model, word2index, index2word)

print(f"Semantic Accuracy: {semantic_accuracy * 100:.2f}%")
print(f"Syntactic Accuracy: {syntactic_accuracy * 100:.2f}%")

# %% [markdown]
# ## 8. Correlation

# %%
from scipy.stats import spearmanr
import torch.nn.functional as F
import numpy as np

def parse_similarity_file(filepath):
    word_pairs = []
    human_scores = []

    with open(filepath, 'r') as file:
        for line in file:
            words = line.split()
            if len(words) == 3:
                word1, word2, score = words
                word_pairs.append((word1, word2))
                human_scores.append(float(score))
    
    return word_pairs, human_scores

# %%
def compute_model_similarity(model, word2index, word_pairs):
    similarities = []
    for word1, word2 in word_pairs:
        if word1 in word2index and word2 in word2index:
            word1_idx = torch.LongTensor([word2index[word1]])
            word2_idx = torch.LongTensor([word2index[word2]])
            
            word1_embed = model.embedding_v(word1_idx)
            word2_embed = model.embedding_v(word2_idx)
            
            # Cosine similarity
            sim = F.cosine_similarity(word1_embed, word2_embed, dim=1).item()
            similarities.append(sim)
        else:
            similarities.append(0.0)  # Assign 0 if either word is out of vocabulary
    
    return similarities

# %%
def calculate_metrics(human_scores, model_scores):
    # Spearman correlation
    spearman_corr, _ = spearmanr(human_scores, model_scores)
    
    # Mean Squared Error
    mse = np.mean((np.array(human_scores) - np.array(model_scores)) ** 2)
    
    return spearman_corr, mse

# %%
# usage
all_spearman_corrs = []
all_mses = []

filepaths = [
    'wordsim_relatedness_goldstandard.txt',
    'wordsim_similarity_goldstandard.txt',
    'wordsim353_agreed.txt',
    'wordsim353_annotator1.txt',
    'wordsim353_annotator2.txt',
]

for filepath in filepaths:
    # Parse the similarity dataset
    word_pairs, human_scores = parse_similarity_file(filepath)
    
    # Compute model similarities
    model_scores = compute_model_similarity(model, word2index, word_pairs)
    
    # Calculate metrics
    spearman_corr, mse = calculate_metrics(human_scores, model_scores)
    all_spearman_corrs.append(spearman_corr)
    all_mses.append(mse)
    
    print(f"File: {filepath}")
    print(f"Spearman Correlation: {spearman_corr:.4f}")
    print(f"MSE: {mse:.4f}\n")

# %%
# Average metrics across all files
avg_spearman_corr = np.mean(all_spearman_corrs)
avg_mse = np.mean(all_mses)

print(f"Average Spearman Correlation: {avg_spearman_corr:.4f}")
print(f"Average MSE: {avg_mse:.4f}")
